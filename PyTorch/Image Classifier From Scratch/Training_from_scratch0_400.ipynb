# %% [markdown]
# # NOTES :
# I have not been able to achieve 85% accuracy (as you will see, the best the model could do was 83% after 400 epochs). After trying several different architectures, I have to ask you to please review my network and suggest improvements. I will retrain the network once I have your input.

# %% [markdown]
# # <font style="color:blue">Project 1 - Part 2: Train an Image Classifier from Scratch</font>
# As discussed in the previous notebook, the steps for training Neural Networks are:
#
# - Step 1 - Understand your problem
# - Step 2A - Get the data
# - Step 2B - Explore & Understand your data
# - Step 2C - Create a sample data from the dataset
# - Step 3 - Data Preparation
# - Step 4 - Train a simple model on sample data and check the pipeline before proceeding to train the full network
# - Step 5 - Train on Full Data
# - Step 6 - Improve your model
#
# You have already gone through Steps 1 through 4 in the previous notebook and you can use them in this notebook as well.
#
# In this notebook You will implement Steps 5 & 6 completely from scratch. You should design a model which achieves 85% validation accuracy on the given dataset.
#
# There are **70 points** for this notebook. <font style="color:red">The sections which carry marks are written in Red for easy reference.</font>

# %% [markdown]
# Since you have received Microsoft Azure Credits, you can use the GPUs for training the network (We will provide instructions on how to set it up in case you are not able to figure it out yourself). After you have completed the assignment, upload and submit it on the portal so that we can check and provide feedback.

# %% [markdown]
# <font style="color:red">You will use the full data to train the network. You need to achieve 85% accuracy for validation data to successfully complete this assignment.</font>
#
# <font style="color:red">As mentioned earlier, you should build your own model and not use any pre-trained models/weights.</font>
#
# After you have completed the assignment, <font style="color:red">upload and submit the notebook and the models folder on the portal</font> so that we can check and provide feedback.

# %% [markdown]
# # <font style="color:blue">Step 1: Understand your problem </font>
# Already covered in previous notebook.

# %% [markdown]
# # <font style="color:blue">Step 2: Get the data </font>
# Already covered in previous notebook.

# %%
#!wget "https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1" -O data.zip

# %% [markdown]
# ### <font style="color:green">Extract the data</font>

# %%
#!unzip -q data.zip

# %% [markdown]
# # <font style="color:blue">Step 3. Data Preparation</font>
# Already covered in previous notebook.

# %% [markdown]
# ## <font style="color:blue">3.1. Import Libraries </font>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import os
import time

from typing import Iterable
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import datasets, transforms

from torch.optim import lr_scheduler

# %% [markdown]
# ### <font style="color:green">3.2.1. Compulsary preprocessing transforms</font>

# %%
def image_preprocess_transforms():
    
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor()
        ])
    
    return preprocess

# %% [markdown]
# ### <font style="color:green">3.2.2. Common Image Transforms</font>

# %%
def image_common_transforms(mean=(0.4611, 0.4359, 0.3905), std=(0.2193, 0.2150, 0.2109)):
    preprocess = image_preprocess_transforms()
    
    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std)
    ])
    
    return common_transforms

# %% [markdown]
# ### <font style="color:green">3.2.3. Mean and STD</font>

# %%
def get_mean_std(data_root, num_workers=4):
    
    transform = image_preprocess_transforms()
    
    loader = data_loader(data_root, transform)

    mean = 0.
    std = 0.
    
    for images, _ in loader:
        batch_samples = images.size(0) # batch size (the last batch can have smaller size!)
        images = images.view(batch_samples, images.size(1), -1)
        mean += images.mean(2).sum(0)
        std += images.std(2).sum(0)

    mean /= len(loader.dataset)
    std /= len(loader.dataset)
    
    print('mean: {}, std: {}'.format(mean, std))
    
    return mean, std

# %% [markdown]
# ## <font style="color:blue">3.3. Data Loaders </font>

# %% [markdown]
# ### <font style="color:green">3.3.1. Data Loader for Full Data</font>
# Data loader for generating batches of data to be used by the training routine

# %%
def data_loader(data_root, transform, batch_size=16, shuffle=False, num_workers=2):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)
    
    loader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %% [markdown]
# ## <font style="color:green">3.4. Prepare Data</font>
# The main function which uses all the above functions to generate the train and test dataloaders.

# %%
def get_data(batch_size, data_root, num_workers=4, data_augmentation=False):

    train_data_path = os.path.join(data_root, 'training')
    mean, std = get_mean_std(data_root=train_data_path, num_workers=num_workers)
    
    common_transforms = image_common_transforms(mean, std)
        
    # if data_augmentation is true 
    # data augmentation implementation
    if data_augmentation:    
        train_transforms = transforms.Compose([ # 1. need to define random augmentation
            #transforms.RandomChoice([
            #    transforms.RandomHorizontalFlip(),
            #    transforms.RandomVerticalFlip(),
            #    transforms.RandomRotation(20, fill=(0,0,0))
            #]),
            transforms.RandomHorizontalFlip(),
            transforms.RandomVerticalFlip(),
            transforms.RandomResizedCrop(256),
            transforms.RandomRotation(20, fill=(0,0,0)),
            transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize(mean, std),
            transforms.RandomErasing()
        ])
    # else do common transforms
    else:
        train_transforms = common_transforms
        
    # train dataloader
    train_loader = data_loader(train_data_path, 
                               train_transforms, 
                               batch_size=batch_size, 
                               shuffle=True, 
                               num_workers=num_workers)
    
    # test dataloader
    test_data_path = os.path.join(data_root, 'validation')
    test_loader = data_loader(test_data_path, 
                              common_transforms, # 2. must be common transforms only
                              batch_size=batch_size, 
                              shuffle=False, 
                              num_workers=num_workers)
    print("Train Size: {}".format(len(train_loader.dataset)))
    print("Validation Size: {}".format(len(test_loader.dataset)))
    return train_loader, test_loader

# %% [markdown]
# # <font style="color:blue">Step 4: Train your Model</font>
# It is time to create the training pipeline and train your model on the full data.

# %% [markdown]
# ## <font style="color:red">4.1. Configurations [20 Points]</font>
# You need to make changes to the configurations. To achieve good results the parameters given in these configurations needs to be changed. You get 10 points for making the right choices.

# %% [markdown]
# ### <font style="color:green">4.1.1. System Configuration</font>
# **DO NOT CHANGE** the seed from 21. We will not be able to grade your project if that happens.

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 21  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# ### <font style="color:green">4.1.2. Training Configuration</font>

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 4 
    epochs_count: int = 400  
    init_learning_rate: float = 0.0001  # initial learning rate for lr scheduler
    log_interval: int = 5  
    test_interval: int = 1  
    data_root: str = "./cat-dog-panda" 
    num_workers: int = 2  
    device: str = 'cuda'

# %% [markdown]
# ### <font style="color:green">4.1.3. System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# ## <font style="color:blue">4.2. Training Function</font>
# We are already familiar with the training function. You won't need to make any changes to this.

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int
) -> None:
    
    # change model in training mood
    model.train()
    
    # to get batch loss
    batch_loss = np.array([])
    
    # to get batch accuracy
    batch_acc = np.array([])
        
    for batch_idx, (data, target) in enumerate(train_loader):
        
        # clone target
        indx_target = target.clone()
        # send data to device (its is medatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()
        
        # forward pass to the model
        output = model(data)
        
        # cross entropy loss
        loss = F.cross_entropy(output, target)
        
        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gardients
        optimizer.step()
        
        batch_loss = np.append(batch_loss, [loss.item()])
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
            
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]  
                        
        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()
            
        # accuracy
        acc = float(correct) / float(len(data))
        
        batch_acc = np.append(batch_acc, [acc])
            
    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    print('Epoch: {} \nTrain Loss: {:.6f} Acc: {:.4f}'.format(epoch_idx, epoch_loss, epoch_acc))
    return epoch_loss, epoch_acc

# %% [markdown]
# ## <font style="color:blue">4.3. Validation Function</font>

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader,
) -> float:
    # 
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)
        
        target = target.to(train_config.device)
        
        output = model(data)
        # add loss for each mini batch
        test_loss += F.cross_entropy(output, target).item()
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
        
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1] 
        
        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)  
    
    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
    
    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )
    
    return test_loss, accuracy/100.0

# %% [markdown]
# ## <font style="color:blue">4.4. Save the Model</font>

# %%
def save_model(model, device, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    model_path = os.path.join(model_dir, model_file_name)

    # make sure you transfer the model to cpu.
    if device == 'cuda':
        model.to('cpu')

    # save the state_dict
    torch.save(model.state_dict(), model_path)
    
    if device == 'cuda':
        model.to('cuda')
    
    return

# %% [markdown]
# ## <font style="color:blue">4.5. Load the Model</font>

# %%
def load_model(model, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    model_path = os.path.join(model_dir, model_file_name)

    # loading the model and getting model parameters by using load_state_dict
    model.load_state_dict(torch.load(model_path))
    
    return model

# %% [markdown]
# ## <font style="color:blue">4.6. Main Function for Training</font>
#
# One thing to note here is that before calling the train function, we are calculating the validation loss and we know that it should be close to `log(num_classes)` and the accuracy should be close to `1/num_classes`.

# %%
def main(model, optimizer, scheduler=None, system_configuration=SystemConfiguration(), 
         training_configuration=TrainingConfiguration(), data_augmentation=True):
    
    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count

    # if GPU is available use training config, 
    # else lowers batch_size, num_workers and epochs count
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
        batch_size_to_set = 16
        num_workers_to_set = 4

    # data loader
    train_loader, test_loader = get_data(
        batch_size=batch_size_to_set,
        data_root=training_configuration.data_root,
        num_workers=num_workers_to_set,
        data_augmentation=data_augmentation
    )
    
    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set
    )
        
    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    best_loss = torch.tensor(np.inf)
    
    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])
    
    # epch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])
    
    # Calculate Initial Test Loss
    init_val_loss, init_val_accuracy = validate(training_configuration, model, test_loader)
    print("Initial Test Loss : {:.6f}, \nInitial Test Accuracy : {:.3f}%\n".format(init_val_loss, 
                                                                                   init_val_accuracy*100))
    
    # trainig time measurement
    t_begin = time.time()
    for epoch in range(training_configuration.epochs_count):
        
        # Train
        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch)
        
        epoch_train_loss = np.append(epoch_train_loss, [train_loss])
        
        epoch_train_acc = np.append(epoch_train_acc, [train_acc])

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time
        
        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )

        # Validate
        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)
            
            epoch_test_loss = np.append(epoch_test_loss, [current_loss])
        
            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])
            
            if current_loss < best_loss:
                best_loss = current_loss
                print('Model Improved. Saving the Model...\n')
                save_model(model, device=training_configuration.device)
        
                
    print("Total time: {:.2f}, Best Loss: {:.3f}".format(time.time() - t_begin, best_loss))
    
    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %% [markdown]
# ## <font style="color:blue">4.7. Plot Loss and Accuracy</font>

# %%
def plot_loss_accuracy(train_loss, val_loss, train_acc, val_acc, colors, 
                       loss_legend_loc='upper center', acc_legend_loc='upper left', 
                       fig_size=(20, 10), sub_plot1=(1, 2, 1), sub_plot2=(1, 2, 2)):
    
    plt.rcParams["figure.figsize"] = fig_size
    fig = plt.figure()
    
    plt.subplot(sub_plot1[0], sub_plot1[1], sub_plot1[2])
    
    for i in range(len(train_loss)):
        x_train = range(len(train_loss[i]))
        x_val = range(len(val_loss[i]))
        
        min_train_loss = train_loss[i].min()
        
        min_val_loss = val_loss[i].min()
        
        plt.plot(x_train, train_loss[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN LOSS ({0:.4})".format(min_train_loss))
        plt.plot(x_val, val_loss[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID LOSS ({0:.4})".format(min_val_loss))
        
    plt.xlabel('epoch no.')
    plt.ylabel('loss')
    plt.legend(loc=loss_legend_loc)
    plt.title('Training and Validation Loss')
        
    plt.subplot(sub_plot2[0], sub_plot2[1], sub_plot2[2])
    
    for i in range(len(train_acc)):
        x_train = range(len(train_acc[i]))
        x_val = range(len(val_acc[i]))
        
        max_train_acc = train_acc[i].max() 
        
        max_val_acc = val_acc[i].max() 
        
        plt.plot(x_train, train_acc[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN ACC ({0:.4})".format(max_train_acc))
        plt.plot(x_val, val_acc[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID ACC ({0:.4})".format(max_val_acc))
        
    plt.xlabel('epoch no.')
    plt.ylabel('accuracy')
    plt.legend(loc=acc_legend_loc)
    plt.title('Training and Validation Accuracy')
    
    fig.savefig('sample_loss_acc_plot.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:red">4.8. Define Model [20 Points]</font>
#
# In the section, you will define the CNN model. You need to keep iterating by training various models by changing:
#     - Number of layers
#     - Parameters inside the layers
#     - different types of layers

# %%
class MyModel(nn.Module):
    def __init__(self, dropout=0.0, batch_norm=False):
        super().__init__()

        # convolution layers
        if batch_norm:
            self._body = nn.Sequential( # input is 3x224x224, output is 32x224x224
                nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5, padding=2),
                nn.BatchNorm2d(32),
                nn.ReLU(inplace=True),
                # input is 32x224x224, output is 64x224x224
                nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, padding=2),
                nn.BatchNorm2d(64),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2), # output is 64x112x112
                
                # input is 64x112x112, output is 64x112x112
                nn.Conv2d(in_channels=64, out_channels=64, kernel_size=5, padding=2),
                nn.BatchNorm2d(64),
                nn.ReLU(inplace=True),
                nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
                nn.BatchNorm2d(128),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2), # output is 128x56x56
                
                nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
                nn.BatchNorm2d(128),
                nn.ReLU(inplace=True),
                nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
                nn.BatchNorm2d(256),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2), # output is 256x28x28
                nn.Dropout(dropout)
            )
        else:
            self._body = nn.Sequential(
                nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5, padding=2),
                nn.ReLU(inplace=True),

                nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, padding=2),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2), # output is 64x112x112

                nn.Conv2d(in_channels=64, out_channels=64, kernel_size=5, padding=2),
                nn.ReLU(inplace=True),
                nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2), # output is 128x56x56

                nn.Conv2d(in_channels=128, out_channels=128, kernel_size=5, padding=2),
                nn.ReLU(inplace=True),
                nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2), # output is 256x28x28

                nn.Dropout(dropout)
            )
            
        # Fully connected layers
        self._head = nn.Sequential(
            
            nn.Linear(in_features=256*28*28, out_features=1024), 
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            
            nn.Linear(in_features=1024, out_features=512), 
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            
            nn.Linear(in_features=512, out_features=3)
        )

    def forward(self, x):
        x = self._body(x)
        x = x.view(x.size()[0], -1)
        x = self._head(x)
        return x

# %% [markdown]
# ## <font style="color:red">4.9. Training [20 Points]</font>
# You should experiment with
#     - Optimizers and learning rate schedulers [You can even get good results without a learning rate shceduler]
#     - Regularization techniques like Data Augmentation, Dropout, BatchNorm

# %%
model = MyModel(0.25, True)
print(model)

# get optimizer
train_config = TrainingConfiguration()

### CHANGE HERE ###

# optimizer
optimizer = optim.Adam(
    model.parameters(),
    lr = train_config.init_learning_rate
)
# Out:
# MyModel(
#   (_body): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (21): Dropout(p=0.25, inplace=False)
#   )
#   (_head): Sequential(
#     (0): Linear(in_features=200704, out_features=1024, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.25, inplace=False)
#     (6): Linear(in_features=512, out_features=3, bias=True)
#   )
# )

# %%
# train and validate
model, train_loss, train_acc, val_loss, val_acc = main(model, optimizer, scheduler=None, data_augmentation=True)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2400, 0.2356, 0.2306])
# Train Size: 2400
# Validation Size: 600
#
# Test set: Average loss: 1.0987, Accuracy: 200/600 (33%)
#
# Initial Test Loss : 1.098651,
# Initial Test Accuracy : 33.333%
#
# Epoch: 0
# Train Loss: 1.396792 Acc: 0.4408
# Elapsed 205.19s, 205.19 s/epoch, 0.34 s/batch, ets 81872.67s
#
# Test set: Average loss: 0.8695, Accuracy: 334/600 (56%)
#
# Model Improved. Saving the Model...
#
# Epoch: 1
# Train Loss: 1.014948 Acc: 0.4767
# Elapsed 429.96s, 214.98 s/epoch, 0.36 s/batch, ets 85562.54s
#
# Test set: Average loss: 0.8666, Accuracy: 326/600 (54%)
#
# Model Improved. Saving the Model...
#
# Epoch: 2
# Train Loss: 0.990316 Acc: 0.4708
# Elapsed 654.20s, 218.07 s/epoch, 0.36 s/batch, ets 86572.76s
#
# Test set: Average loss: 0.8677, Accuracy: 321/600 (54%)
#
# Epoch: 3
# Train Loss: 1.002085 Acc: 0.4896
# Elapsed 869.88s, 217.47 s/epoch, 0.36 s/batch, ets 86117.70s
#
# Test set: Average loss: 0.8620, Accuracy: 332/600 (55%)
#
# Model Improved. Saving the Model...
#
# Epoch: 4
# Train Loss: 0.975429 Acc: 0.4971
# Elapsed 1094.10s, 218.82 s/epoch, 0.36 s/batch, ets 86433.79s
#
# Test set: Average loss: 0.8243, Accuracy: 324/600 (54%)
#
# Model Improved. Saving the Model...
#
# Epoch: 5
# Train Loss: 0.964120 Acc: 0.4879
# Elapsed 1318.66s, 219.78 s/epoch, 0.37 s/batch, ets 86592.19s
#
# Test set: Average loss: 2.2291, Accuracy: 258/600 (43%)
#
# Epoch: 6
# Train Loss: 0.942410 Acc: 0.5058
# Elapsed 1534.52s, 219.22 s/epoch, 0.37 s/batch, ets 86152.22s
#
# Test set: Average loss: 0.8192, Accuracy: 315/600 (52%)
#
# Model Improved. Saving the Model...
#
# Epoch: 7
# Train Loss: 0.950615 Acc: 0.5071
# Elapsed 1760.25s, 220.03 s/epoch, 0.37 s/batch, ets 86252.18s
#
# Test set: Average loss: 0.8825, Accuracy: 324/600 (54%)
#
# Epoch: 8
# Train Loss: 0.919072 Acc: 0.5171
# Elapsed 1975.93s, 219.55 s/epoch, 0.37 s/batch, ets 85843.26s
#
# Test set: Average loss: 0.7950, Accuracy: 330/600 (55%)
#
# Model Improved. Saving the Model...
#
# Epoch: 9
# Train Loss: 0.882495 Acc: 0.5408
# Elapsed 2201.34s, 220.13 s/epoch, 0.37 s/batch, ets 85852.18s
#
# Test set: Average loss: 0.7125, Accuracy: 368/600 (61%)
#
# Model Improved. Saving the Model...
#
# Epoch: 10
# Train Loss: 0.862586 Acc: 0.5471
# Elapsed 2428.12s, 220.74 s/epoch, 0.37 s/batch, ets 85867.16s
#
# Test set: Average loss: 0.7865, Accuracy: 351/600 (58%)
#
# Epoch: 11
# Train Loss: 0.851052 Acc: 0.5546
# Elapsed 2643.82s, 220.32 s/epoch, 0.37 s/batch, ets 85483.52s
#
# Test set: Average loss: 0.7410, Accuracy: 339/600 (56%)
#
# Epoch: 12
# Train Loss: 0.841313 Acc: 0.5571
# Elapsed 2859.66s, 219.97 s/epoch, 0.37 s/batch, ets 85129.96s
#
# Test set: Average loss: 0.7215, Accuracy: 354/600 (59%)
#
# Epoch: 13
# Train Loss: 0.783395 Acc: 0.5592
# Elapsed 3075.36s, 219.67 s/epoch, 0.37 s/batch, ets 84791.99s
#
# Test set: Average loss: 0.6714, Accuracy: 383/600 (64%)
#
# Model Improved. Saving the Model...
#
# Epoch: 14
# Train Loss: 0.798102 Acc: 0.5663
# Elapsed 3300.77s, 220.05 s/epoch, 0.37 s/batch, ets 84719.73s
#
# Test set: Average loss: 0.7202, Accuracy: 348/600 (58%)
#
# Epoch: 15
# Train Loss: 0.769860 Acc: 0.5667
# Elapsed 3516.47s, 219.78 s/epoch, 0.37 s/batch, ets 84395.21s
#
# Test set: Average loss: 0.7028, Accuracy: 366/600 (61%)
#
# Epoch: 16
# Train Loss: 0.789460 Acc: 0.5696
# Elapsed 3732.15s, 219.54 s/epoch, 0.37 s/batch, ets 84083.21s
#
# Test set: Average loss: 0.7047, Accuracy: 363/600 (60%)
#
# Epoch: 17
# Train Loss: 0.752066 Acc: 0.5758
# Elapsed 3948.03s, 219.33 s/epoch, 0.37 s/batch, ets 83785.89s
#
# Test set: Average loss: 0.6738, Accuracy: 370/600 (62%)
#
# Epoch: 18
# Train Loss: 0.739999 Acc: 0.5833
# Elapsed 4163.72s, 219.14 s/epoch, 0.37 s/batch, ets 83493.55s
#
# Test set: Average loss: 0.6361, Accuracy: 372/600 (62%)
#
# Model Improved. Saving the Model...
#
# Epoch: 19
# Train Loss: 0.729182 Acc: 0.5813
# Elapsed 4388.78s, 219.44 s/epoch, 0.37 s/batch, ets 83386.84s
#
# Test set: Average loss: 0.6791, Accuracy: 363/600 (60%)
#
# Epoch: 20
# Train Loss: 0.733387 Acc: 0.5892
# Elapsed 4604.47s, 219.26 s/epoch, 0.37 s/batch, ets 83099.77s
#
# Test set: Average loss: 0.6943, Accuracy: 382/600 (64%)
#
# Epoch: 21
# Train Loss: 0.725303 Acc: 0.5758
# Elapsed 4820.15s, 219.10 s/epoch, 0.37 s/batch, ets 82819.03s
#
# Test set: Average loss: 0.6882, Accuracy: 358/600 (60%)
#
# Epoch: 22
# Train Loss: 0.697148 Acc: 0.5900
# Elapsed 5035.83s, 218.95 s/epoch, 0.36 s/batch, ets 82543.89s
#
# Test set: Average loss: 0.7039, Accuracy: 350/600 (58%)
#
# Epoch: 23
# Train Loss: 0.710627 Acc: 0.5925
# Elapsed 5251.70s, 218.82 s/epoch, 0.36 s/batch, ets 82276.56s
#
# Test set: Average loss: 0.6336, Accuracy: 374/600 (62%)
#
# Model Improved. Saving the Model...
#
# Epoch: 24
# Train Loss: 0.723012 Acc: 0.5892
# Elapsed 5477.62s, 219.10 s/epoch, 0.37 s/batch, ets 82164.37s
#
# Test set: Average loss: 0.6569, Accuracy: 366/600 (61%)
#
# Epoch: 25
# Train Loss: 0.700845 Acc: 0.5967
# Elapsed 5693.47s, 218.98 s/epoch, 0.36 s/batch, ets 81898.40s
#
# Test set: Average loss: 0.6730, Accuracy: 367/600 (61%)
#
# Epoch: 26
# Train Loss: 0.701941 Acc: 0.5804
# Elapsed 5909.33s, 218.86 s/epoch, 0.36 s/batch, ets 81636.35s
#
# Test set: Average loss: 0.6442, Accuracy: 378/600 (63%)
#
# Epoch: 27
# Train Loss: 0.689593 Acc: 0.6033
# Elapsed 6125.02s, 218.75 s/epoch, 0.36 s/batch, ets 81375.27s
#
# Test set: Average loss: 0.6694, Accuracy: 377/600 (63%)
#
# Epoch: 28
# Train Loss: 0.671475 Acc: 0.6000
# Elapsed 6340.70s, 218.64 s/epoch, 0.36 s/batch, ets 81117.29s
#
# Test set: Average loss: 0.6404, Accuracy: 367/600 (61%)
#
# Epoch: 29
# Train Loss: 0.672283 Acc: 0.6104
# Elapsed 6556.55s, 218.55 s/epoch, 0.36 s/batch, ets 80864.07s
#
# Test set: Average loss: 0.6499, Accuracy: 381/600 (64%)
#
# Epoch: 30
# Train Loss: 0.674621 Acc: 0.6133
# Elapsed 6772.23s, 218.46 s/epoch, 0.36 s/batch, ets 80611.44s
#
# Test set: Average loss: 0.6137, Accuracy: 388/600 (65%)
#
# Model Improved. Saving the Model...
#
# Epoch: 31
# Train Loss: 0.664328 Acc: 0.6200
# Elapsed 6998.65s, 218.71 s/epoch, 0.36 s/batch, ets 80484.50s
#
# Test set: Average loss: 0.6797, Accuracy: 374/600 (62%)
#
# Epoch: 32
# Train Loss: 0.668256 Acc: 0.6154
# Elapsed 7214.31s, 218.62 s/epoch, 0.36 s/batch, ets 80231.85s
#
# Test set: Average loss: 0.6368, Accuracy: 371/600 (62%)
#
# Epoch: 33
# Train Loss: 0.661944 Acc: 0.6183
# Elapsed 7430.00s, 218.53 s/epoch, 0.36 s/batch, ets 79981.72s
#
# Test set: Average loss: 0.6144, Accuracy: 373/600 (62%)
#
# Epoch: 34
# Train Loss: 0.665190 Acc: 0.6325
# Elapsed 7645.86s, 218.45 s/epoch, 0.36 s/batch, ets 79735.35s
#
# Test set: Average loss: 0.6169, Accuracy: 373/600 (62%)
#
# Epoch: 35
# Train Loss: 0.657714 Acc: 0.6254
# Elapsed 7861.54s, 218.38 s/epoch, 0.36 s/batch, ets 79488.89s
#
# Test set: Average loss: 0.6304, Accuracy: 372/600 (62%)
#
# Epoch: 36
# Train Loss: 0.657711 Acc: 0.6121
# Elapsed 8077.41s, 218.31 s/epoch, 0.36 s/batch, ets 79245.91s
#
# Test set: Average loss: 0.6435, Accuracy: 370/600 (62%)
#
# Epoch: 37
# Train Loss: 0.648225 Acc: 0.6121
# Elapsed 8293.11s, 218.24 s/epoch, 0.36 s/batch, ets 79002.83s
#
# Test set: Average loss: 0.6593, Accuracy: 355/600 (59%)
#
# Epoch: 38
# Train Loss: 0.653972 Acc: 0.6312
# Elapsed 8508.78s, 218.17 s/epoch, 0.36 s/batch, ets 78760.75s
#
# Test set: Average loss: 0.6437, Accuracy: 393/600 (66%)
#
# Epoch: 39
# Train Loss: 0.656812 Acc: 0.6262
# Elapsed 8724.45s, 218.11 s/epoch, 0.36 s/batch, ets 78520.09s
#
# Test set: Average loss: 0.6432, Accuracy: 376/600 (63%)
#
# Epoch: 40
# Train Loss: 0.668846 Acc: 0.6008
# Elapsed 8940.32s, 218.06 s/epoch, 0.36 s/batch, ets 78282.31s
#
# Test set: Average loss: 0.6214, Accuracy: 375/600 (62%)
#
# Epoch: 41
# Train Loss: 0.645248 Acc: 0.6292
# Elapsed 9156.00s, 218.00 s/epoch, 0.36 s/batch, ets 78043.99s
#
# Test set: Average loss: 0.6227, Accuracy: 376/600 (63%)
#
# Epoch: 42
# Train Loss: 0.653366 Acc: 0.6125
# Elapsed 9371.67s, 217.95 s/epoch, 0.36 s/batch, ets 77806.66s
#
# Test set: Average loss: 0.6209, Accuracy: 372/600 (62%)
#
# Epoch: 43
# Train Loss: 0.651184 Acc: 0.6179
# Elapsed 9587.36s, 217.89 s/epoch, 0.36 s/batch, ets 77570.45s
#
# Test set: Average loss: 0.6540, Accuracy: 385/600 (64%)
#
# Epoch: 44
# Train Loss: 0.650813 Acc: 0.6296
# Elapsed 9803.04s, 217.85 s/epoch, 0.36 s/batch, ets 77335.12s
#
# Test set: Average loss: 0.6448, Accuracy: 378/600 (63%)
#
# Epoch: 45
# Train Loss: 0.638687 Acc: 0.6254
# Elapsed 10018.72s, 217.80 s/epoch, 0.36 s/batch, ets 77100.57s
#
# Test set: Average loss: 0.6519, Accuracy: 376/600 (63%)
#
# Epoch: 46
# Train Loss: 0.650997 Acc: 0.6321
# Elapsed 10234.42s, 217.75 s/epoch, 0.36 s/batch, ets 76867.01s
#
# Test set: Average loss: 0.6660, Accuracy: 368/600 (61%)
#
# Epoch: 47
# Train Loss: 0.651152 Acc: 0.6262
# Elapsed 10450.09s, 217.71 s/epoch, 0.36 s/batch, ets 76633.98s
#
# Test set: Average loss: 0.8022, Accuracy: 377/600 (63%)
#
# Epoch: 48
# Train Loss: 0.657751 Acc: 0.6175
# Elapsed 10665.78s, 217.67 s/epoch, 0.36 s/batch, ets 76401.79s
#
# Test set: Average loss: 0.5962, Accuracy: 385/600 (64%)
#
# Model Improved. Saving the Model...
#
# Epoch: 49
# Train Loss: 0.654719 Acc: 0.6150
# Elapsed 10891.36s, 217.83 s/epoch, 0.36 s/batch, ets 76239.50s
#
# Test set: Average loss: 0.7004, Accuracy: 373/600 (62%)
#
# Epoch: 50
# Train Loss: 0.669387 Acc: 0.6033
# Elapsed 11107.06s, 217.79 s/epoch, 0.36 s/batch, ets 76007.15s
#
# Test set: Average loss: 0.6510, Accuracy: 365/600 (61%)
#
# Epoch: 51
# Train Loss: 0.659119 Acc: 0.6179
# Elapsed 11322.74s, 217.74 s/epoch, 0.36 s/batch, ets 75775.26s
#
# Test set: Average loss: 0.6357, Accuracy: 399/600 (66%)
#
# Epoch: 52
# Train Loss: 0.634879 Acc: 0.6246
# Elapsed 11538.41s, 217.71 s/epoch, 0.36 s/batch, ets 75543.93s
#
# Test set: Average loss: 0.6267, Accuracy: 382/600 (64%)
#
# Epoch: 53
# Train Loss: 0.663685 Acc: 0.6221
# Elapsed 11754.08s, 217.67 s/epoch, 0.36 s/batch, ets 75313.19s
#
# Test set: Average loss: 0.6525, Accuracy: 375/600 (62%)
#
# Epoch: 54
# Train Loss: 0.656017 Acc: 0.6238
# Elapsed 11969.77s, 217.63 s/epoch, 0.36 s/batch, ets 75083.12s
#
# Test set: Average loss: 0.6190, Accuracy: 388/600 (65%)
#
# Epoch: 55
# Train Loss: 0.637780 Acc: 0.6142
# Elapsed 12185.48s, 217.60 s/epoch, 0.36 s/batch, ets 74853.64s
#
# Test set: Average loss: 0.6323, Accuracy: 379/600 (63%)
#
# Epoch: 56
# Train Loss: 0.652272 Acc: 0.6146
# Elapsed 12401.16s, 217.56 s/epoch, 0.36 s/batch, ets 74624.54s
#
# Test set: Average loss: 0.6065, Accuracy: 387/600 (64%)
#
# Epoch: 57
# Train Loss: 0.640677 Acc: 0.6425
# Elapsed 12616.99s, 217.53 s/epoch, 0.36 s/batch, ets 74396.74s
#
# Test set: Average loss: 0.6281, Accuracy: 389/600 (65%)
#
# Epoch: 58
# Train Loss: 0.643773 Acc: 0.6288
# Elapsed 12832.65s, 217.50 s/epoch, 0.36 s/batch, ets 74168.38s
#
# Test set: Average loss: 0.6152, Accuracy: 398/600 (66%)
#
# Epoch: 59
# Train Loss: 0.636353 Acc: 0.6262
# Elapsed 13048.33s, 217.47 s/epoch, 0.36 s/batch, ets 73940.53s
#
# Test set: Average loss: 0.6013, Accuracy: 381/600 (64%)
#
# Epoch: 60
# Train Loss: 0.652025 Acc: 0.6400
# Elapsed 13263.97s, 217.44 s/epoch, 0.36 s/batch, ets 73712.91s
#
# Test set: Average loss: 0.6284, Accuracy: 386/600 (64%)
#
# Epoch: 61
# Train Loss: 0.629031 Acc: 0.6388
# Elapsed 13479.66s, 217.41 s/epoch, 0.36 s/batch, ets 73485.90s
#
# Test set: Average loss: 0.6177, Accuracy: 400/600 (67%)
#
# Epoch: 62
# Train Loss: 0.638248 Acc: 0.6233
# Elapsed 13695.51s, 217.39 s/epoch, 0.36 s/batch, ets 73260.10s
#
# Test set: Average loss: 0.6435, Accuracy: 393/600 (66%)
#
# Epoch: 63
# Train Loss: 0.620393 Acc: 0.6333
# Elapsed 13911.38s, 217.37 s/epoch, 0.36 s/batch, ets 73034.73s
#
# Test set: Average loss: 0.6370, Accuracy: 403/600 (67%)
#
# Epoch: 64
# Train Loss: 0.626662 Acc: 0.6246
# Elapsed 14127.02s, 217.34 s/epoch, 0.36 s/batch, ets 72808.50s
#
# Test set: Average loss: 0.6226, Accuracy: 397/600 (66%)
#
# Epoch: 65
# Train Loss: 0.642057 Acc: 0.6312
# Elapsed 14342.70s, 217.31 s/epoch, 0.36 s/batch, ets 72582.75s
#
# Test set: Average loss: 0.6103, Accuracy: 374/600 (62%)
#
# Epoch: 66
# Train Loss: 0.642765 Acc: 0.6379
# Elapsed 14558.39s, 217.29 s/epoch, 0.36 s/batch, ets 72357.35s
#
# Test set: Average loss: 0.6270, Accuracy: 406/600 (68%)
#
# Epoch: 67
# Train Loss: 0.641809 Acc: 0.6408
# Elapsed 14774.24s, 217.27 s/epoch, 0.36 s/batch, ets 72133.06s
#
# Test set: Average loss: 0.6270, Accuracy: 396/600 (66%)
#
# Epoch: 68
# Train Loss: 0.676109 Acc: 0.6408
# Elapsed 14989.93s, 217.25 s/epoch, 0.36 s/batch, ets 71908.21s
#
# Test set: Average loss: 0.6050, Accuracy: 407/600 (68%)
#
# Epoch: 69
# Train Loss: 0.635171 Acc: 0.6379
# Elapsed 15205.79s, 217.23 s/epoch, 0.36 s/batch, ets 71684.42s
#
# Test set: Average loss: 0.6227, Accuracy: 379/600 (63%)
#
# Epoch: 70
# Train Loss: 0.637549 Acc: 0.6504
# Elapsed 15421.45s, 217.20 s/epoch, 0.36 s/batch, ets 71459.94s
#
# Test set: Average loss: 0.5974, Accuracy: 389/600 (65%)
#
# Epoch: 71
# Train Loss: 0.635020 Acc: 0.6579
# Elapsed 15637.13s, 217.18 s/epoch, 0.36 s/batch, ets 71235.83s
#
# Test set: Average loss: 0.6248, Accuracy: 406/600 (68%)
#
# Epoch: 72
# Train Loss: 0.616349 Acc: 0.6375
# Elapsed 15852.81s, 217.16 s/epoch, 0.36 s/batch, ets 71011.91s
#
# Test set: Average loss: 0.6416, Accuracy: 376/600 (63%)
#
# Epoch: 73
# Train Loss: 0.622538 Acc: 0.6621
# Elapsed 16068.65s, 217.14 s/epoch, 0.36 s/batch, ets 70788.93s
#
# Test set: Average loss: 0.5913, Accuracy: 399/600 (66%)
#
# Model Improved. Saving the Model...
#
# Epoch: 74
# Train Loss: 0.661256 Acc: 0.6412
# Elapsed 16295.08s, 217.27 s/epoch, 0.36 s/batch, ets 70612.00s
#
# Test set: Average loss: 0.6244, Accuracy: 404/600 (67%)
#
# Epoch: 75
# Train Loss: 0.627325 Acc: 0.6450
# Elapsed 16510.95s, 217.25 s/epoch, 0.36 s/batch, ets 70388.79s
#
# Test set: Average loss: 0.6118, Accuracy: 406/600 (68%)
#
# Epoch: 76
# Train Loss: 0.625703 Acc: 0.6412
# Elapsed 16726.66s, 217.23 s/epoch, 0.36 s/batch, ets 70165.08s
#
# Test set: Average loss: 0.6103, Accuracy: 380/600 (63%)
#
# Epoch: 77
# Train Loss: 0.638403 Acc: 0.6483
# Elapsed 16942.34s, 217.21 s/epoch, 0.36 s/batch, ets 69941.45s
#
# Test set: Average loss: 0.6068, Accuracy: 384/600 (64%)
#
# Epoch: 78
# Train Loss: 0.621530 Acc: 0.6271
# Elapsed 17158.19s, 217.19 s/epoch, 0.36 s/batch, ets 69718.74s
#
# Test set: Average loss: 0.6067, Accuracy: 401/600 (67%)
#
# Epoch: 79
# Train Loss: 0.613008 Acc: 0.6492
# Elapsed 17373.87s, 217.17 s/epoch, 0.36 s/batch, ets 69495.46s
#
# Test set: Average loss: 0.6077, Accuracy: 389/600 (65%)
#
# Epoch: 80
# Train Loss: 0.623775 Acc: 0.6442
# Elapsed 17589.55s, 217.15 s/epoch, 0.36 s/batch, ets 69272.43s
#
# Test set: Average loss: 0.6211, Accuracy: 405/600 (68%)
#
# Epoch: 81
# Train Loss: 0.652295 Acc: 0.6300
# Elapsed 17805.39s, 217.14 s/epoch, 0.36 s/batch, ets 69050.17s
#
# Test set: Average loss: 0.6082, Accuracy: 395/600 (66%)
#
# Epoch: 82
# Train Loss: 0.635062 Acc: 0.6446
# Elapsed 18021.09s, 217.12 s/epoch, 0.36 s/batch, ets 68827.54s
#
# Test set: Average loss: 0.5980, Accuracy: 392/600 (65%)
#
# Epoch: 83
# Train Loss: 0.614109 Acc: 0.6425
# Elapsed 18236.78s, 217.10 s/epoch, 0.36 s/batch, ets 68605.02s
#
# Test set: Average loss: 0.6233, Accuracy: 381/600 (64%)
#
# Epoch: 84
# Train Loss: 0.653345 Acc: 0.6392
# Elapsed 18452.45s, 217.09 s/epoch, 0.36 s/batch, ets 68382.61s
#
# Test set: Average loss: 0.6127, Accuracy: 393/600 (66%)
#
# Epoch: 85
# Train Loss: 0.633760 Acc: 0.6400
# Elapsed 18668.12s, 217.07 s/epoch, 0.36 s/batch, ets 68160.36s
#
# Test set: Average loss: 0.6102, Accuracy: 393/600 (66%)
#
# Epoch: 86
# Train Loss: 0.630090 Acc: 0.6462
# Elapsed 18883.98s, 217.06 s/epoch, 0.36 s/batch, ets 67938.92s
#
# Test set: Average loss: 0.5931, Accuracy: 417/600 (70%)
#
# Epoch: 87
# Train Loss: 0.640576 Acc: 0.6412
# Elapsed 19099.67s, 217.04 s/epoch, 0.36 s/batch, ets 67717.02s
#
# Test set: Average loss: 0.6028, Accuracy: 397/600 (66%)
#
# Epoch: 88
# Train Loss: 0.620490 Acc: 0.6383
# Elapsed 19315.34s, 217.03 s/epoch, 0.36 s/batch, ets 67495.18s
#
# Test set: Average loss: 0.5931, Accuracy: 411/600 (68%)
#
# Epoch: 89
# Train Loss: 0.606790 Acc: 0.6429
# Elapsed 19531.20s, 217.01 s/epoch, 0.36 s/batch, ets 67274.13s
#
# Test set: Average loss: 0.5938, Accuracy: 405/600 (68%)
#
# Epoch: 90
# Train Loss: 0.626381 Acc: 0.6425
# Elapsed 19746.86s, 217.00 s/epoch, 0.36 s/batch, ets 67052.54s
#
# Test set: Average loss: 0.6011, Accuracy: 391/600 (65%)
#
# Epoch: 91
# Train Loss: 0.621049 Acc: 0.6488
# Elapsed 19962.72s, 216.99 s/epoch, 0.36 s/batch, ets 66831.72s
#
# Test set: Average loss: 0.5889, Accuracy: 399/600 (66%)
#
# Model Improved. Saving the Model...
#
# Epoch: 92
# Train Loss: 0.613998 Acc: 0.6354
# Elapsed 20187.29s, 217.07 s/epoch, 0.36 s/batch, ets 66639.76s
#
# Test set: Average loss: 0.5934, Accuracy: 376/600 (63%)
#
# Epoch: 93
# Train Loss: 0.623440 Acc: 0.6288
# Elapsed 20403.13s, 217.05 s/epoch, 0.36 s/batch, ets 66418.69s
#
# Test set: Average loss: 0.6081, Accuracy: 403/600 (67%)
#
# Epoch: 94
# Train Loss: 0.627628 Acc: 0.6554
# Elapsed 20618.81s, 217.04 s/epoch, 0.36 s/batch, ets 66197.24s
#
# Test set: Average loss: 0.5819, Accuracy: 421/600 (70%)
#
# Model Improved. Saving the Model...
#
# Epoch: 95
# Train Loss: 0.639375 Acc: 0.6571
# Elapsed 20843.00s, 217.11 s/epoch, 0.36 s/batch, ets 66002.84s
#
# Test set: Average loss: 0.6112, Accuracy: 393/600 (66%)
#
# Epoch: 96
# Train Loss: 0.613717 Acc: 0.6633
# Elapsed 21058.70s, 217.10 s/epoch, 0.36 s/batch, ets 65781.30s
#
# Test set: Average loss: 0.5915, Accuracy: 407/600 (68%)
#
# Epoch: 97
# Train Loss: 0.620809 Acc: 0.6479
# Elapsed 21274.37s, 217.09 s/epoch, 0.36 s/batch, ets 65559.81s
#
# Test set: Average loss: 0.6215, Accuracy: 414/600 (69%)
#
# Epoch: 98
# Train Loss: 0.628077 Acc: 0.6500
# Elapsed 21490.06s, 217.07 s/epoch, 0.36 s/batch, ets 65338.45s
#
# Test set: Average loss: 0.6142, Accuracy: 420/600 (70%)
#
# Epoch: 99
# Train Loss: 0.647605 Acc: 0.6508
# Elapsed 21705.90s, 217.06 s/epoch, 0.36 s/batch, ets 65117.70s
#
# Test set: Average loss: 0.5937, Accuracy: 428/600 (71%)
#
# Epoch: 100
# Train Loss: 0.628774 Acc: 0.6504
# Elapsed 21921.74s, 217.05 s/epoch, 0.36 s/batch, ets 64897.03s
#
# Test set: Average loss: 0.6480, Accuracy: 420/600 (70%)
#
# Epoch: 101
# Train Loss: 0.631169 Acc: 0.6554
# Elapsed 22137.57s, 217.03 s/epoch, 0.36 s/batch, ets 64676.42s
#
# Test set: Average loss: 0.6381, Accuracy: 394/600 (66%)
#
# Epoch: 102
# Train Loss: 0.621389 Acc: 0.6529
# Elapsed 22353.41s, 217.02 s/epoch, 0.36 s/batch, ets 64455.94s
#
# Test set: Average loss: 0.5988, Accuracy: 426/600 (71%)
#
# Epoch: 103
# Train Loss: 0.603058 Acc: 0.6621
# Elapsed 22569.24s, 217.01 s/epoch, 0.36 s/batch, ets 64235.54s
#
# Test set: Average loss: 0.5951, Accuracy: 417/600 (70%)
#
# Epoch: 104
# Train Loss: 0.610089 Acc: 0.6467
# Elapsed 22784.94s, 217.00 s/epoch, 0.36 s/batch, ets 64014.82s
#
# Test set: Average loss: 0.6388, Accuracy: 401/600 (67%)
#
# Epoch: 105
# Train Loss: 0.609463 Acc: 0.6587
# Elapsed 23000.62s, 216.99 s/epoch, 0.36 s/batch, ets 63794.16s
#
# Test set: Average loss: 0.6011, Accuracy: 421/600 (70%)
#
# Epoch: 106
# Train Loss: 0.618626 Acc: 0.6492
# Elapsed 23216.47s, 216.98 s/epoch, 0.36 s/batch, ets 63574.08s
#
# Test set: Average loss: 0.5874, Accuracy: 396/600 (66%)
#
# Epoch: 107
# Train Loss: 0.622177 Acc: 0.6512
# Elapsed 23432.14s, 216.96 s/epoch, 0.36 s/batch, ets 63353.56s
#
# Test set: Average loss: 0.5916, Accuracy: 431/600 (72%)
#
# Epoch: 108
# Train Loss: 0.632856 Acc: 0.6408
# Elapsed 23647.82s, 216.95 s/epoch, 0.36 s/batch, ets 63133.16s
#
# Test set: Average loss: 0.5974, Accuracy: 413/600 (69%)
#
# Epoch: 109
# Train Loss: 0.611866 Acc: 0.6475
# Elapsed 23863.48s, 216.94 s/epoch, 0.36 s/batch, ets 62912.82s
#
# Test set: Average loss: 0.5892, Accuracy: 423/600 (70%)
#
# Epoch: 110
# Train Loss: 0.609194 Acc: 0.6675
# Elapsed 24079.31s, 216.93 s/epoch, 0.36 s/batch, ets 62692.98s
#
# Test set: Average loss: 0.5916, Accuracy: 407/600 (68%)
#
# Epoch: 111
# Train Loss: 0.602040 Acc: 0.6775
# Elapsed 24295.02s, 216.92 s/epoch, 0.36 s/batch, ets 62472.90s
#
# Test set: Average loss: 0.5981, Accuracy: 404/600 (67%)
#
# Epoch: 112
# Train Loss: 0.610136 Acc: 0.6596
# Elapsed 24510.86s, 216.91 s/epoch, 0.36 s/batch, ets 62253.25s
#
# Test set: Average loss: 0.6059, Accuracy: 426/600 (71%)
#
# Epoch: 113
# Train Loss: 0.611704 Acc: 0.6750
# Elapsed 24726.51s, 216.90 s/epoch, 0.36 s/batch, ets 62033.18s
#
# Test set: Average loss: 0.5971, Accuracy: 394/600 (66%)
#
# Epoch: 114
# Train Loss: 0.629390 Acc: 0.6546
# Elapsed 24942.19s, 216.89 s/epoch, 0.36 s/batch, ets 61813.26s
#
# Test set: Average loss: 0.5783, Accuracy: 417/600 (70%)
#
# Model Improved. Saving the Model...
#
# Epoch: 115
# Train Loss: 0.617351 Acc: 0.6483
# Elapsed 25164.53s, 216.94 s/epoch, 0.36 s/batch, ets 61609.70s
#
# Test set: Average loss: 0.6164, Accuracy: 389/600 (65%)
#
# Epoch: 116
# Train Loss: 0.610541 Acc: 0.6721
# Elapsed 25380.37s, 216.93 s/epoch, 0.36 s/batch, ets 61390.13s
#
# Test set: Average loss: 0.6052, Accuracy: 408/600 (68%)
#
# Epoch: 117
# Train Loss: 0.634415 Acc: 0.6571
# Elapsed 25596.04s, 216.92 s/epoch, 0.36 s/batch, ets 61170.20s
#
# Test set: Average loss: 0.5991, Accuracy: 400/600 (67%)
#
# Epoch: 118
# Train Loss: 0.609560 Acc: 0.6683
# Elapsed 25811.73s, 216.91 s/epoch, 0.36 s/batch, ets 60950.38s
#
# Test set: Average loss: 0.5725, Accuracy: 417/600 (70%)
#
# Model Improved. Saving the Model...
#
# Epoch: 119
# Train Loss: 0.610527 Acc: 0.6717
# Elapsed 26035.94s, 216.97 s/epoch, 0.36 s/batch, ets 60750.52s
#
# Test set: Average loss: 0.6174, Accuracy: 400/600 (67%)
#
# Epoch: 120
# Train Loss: 0.610654 Acc: 0.6671
# Elapsed 26251.60s, 216.96 s/epoch, 0.36 s/batch, ets 60530.55s
#
# Test set: Average loss: 0.6115, Accuracy: 423/600 (70%)
#
# Epoch: 121
# Train Loss: 0.616282 Acc: 0.6683
# Elapsed 26467.47s, 216.95 s/epoch, 0.36 s/batch, ets 60311.13s
#
# Test set: Average loss: 0.5757, Accuracy: 428/600 (71%)
#
# Epoch: 122
# Train Loss: 0.598768 Acc: 0.6642
# Elapsed 26683.30s, 216.94 s/epoch, 0.36 s/batch, ets 60091.66s
#
# Test set: Average loss: 0.6199, Accuracy: 424/600 (71%)
#
# Epoch: 123
# Train Loss: 0.613525 Acc: 0.6700
# Elapsed 26899.01s, 216.93 s/epoch, 0.36 s/batch, ets 59871.99s
#
# Test set: Average loss: 0.5814, Accuracy: 412/600 (69%)
#
# Epoch: 124
# Train Loss: 0.613443 Acc: 0.6771
# Elapsed 27114.68s, 216.92 s/epoch, 0.36 s/batch, ets 59652.30s
#
# Test set: Average loss: 0.5938, Accuracy: 417/600 (70%)
#
# Epoch: 125
# Train Loss: 0.606958 Acc: 0.6804
# Elapsed 27330.51s, 216.91 s/epoch, 0.36 s/batch, ets 59433.02s
#
# Test set: Average loss: 0.5928, Accuracy: 409/600 (68%)
#
# Epoch: 126
# Train Loss: 0.609465 Acc: 0.6654
# Elapsed 27546.18s, 216.90 s/epoch, 0.36 s/batch, ets 59213.45s
#
# Test set: Average loss: 0.5885, Accuracy: 412/600 (69%)
#
# Epoch: 127
# Train Loss: 0.605770 Acc: 0.6704
# Elapsed 27761.86s, 216.89 s/epoch, 0.36 s/batch, ets 58993.94s
#
# Test set: Average loss: 0.5736, Accuracy: 432/600 (72%)
#
# Epoch: 128
# Train Loss: 0.616981 Acc: 0.6654
# Elapsed 27977.54s, 216.88 s/epoch, 0.36 s/batch, ets 58774.51s
#
# Test set: Average loss: 0.5956, Accuracy: 402/600 (67%)
#
# Epoch: 129
# Train Loss: 0.611760 Acc: 0.6654
# Elapsed 28193.22s, 216.87 s/epoch, 0.36 s/batch, ets 58555.16s
#
# Test set: Average loss: 0.5851, Accuracy: 417/600 (70%)
#
# Epoch: 130
# Train Loss: 0.617637 Acc: 0.6592
# Elapsed 28409.05s, 216.86 s/epoch, 0.36 s/batch, ets 58336.14s
#
# Test set: Average loss: 0.5846, Accuracy: 397/600 (66%)
#
# Epoch: 131
# Train Loss: 0.607862 Acc: 0.6567
# Elapsed 28624.72s, 216.85 s/epoch, 0.36 s/batch, ets 58116.87s
#
# Test set: Average loss: 0.5850, Accuracy: 421/600 (70%)
#
# Epoch: 132
# Train Loss: 0.622657 Acc: 0.6671
# Elapsed 28840.41s, 216.85 s/epoch, 0.36 s/batch, ets 57897.67s
#
# Test set: Average loss: 0.5744, Accuracy: 420/600 (70%)
#
# Epoch: 133
# Train Loss: 0.616824 Acc: 0.6583
# Elapsed 29056.24s, 216.84 s/epoch, 0.36 s/batch, ets 57678.80s
#
# Test set: Average loss: 0.5829, Accuracy: 406/600 (68%)
#
# Epoch: 134
# Train Loss: 0.610926 Acc: 0.6700
# Elapsed 29271.91s, 216.83 s/epoch, 0.36 s/batch, ets 57459.68s
#
# Test set: Average loss: 0.6104, Accuracy: 426/600 (71%)
#
# Epoch: 135
# Train Loss: 0.608600 Acc: 0.6713
# Elapsed 29487.62s, 216.82 s/epoch, 0.36 s/batch, ets 57240.68s
#
# Test set: Average loss: 0.5694, Accuracy: 419/600 (70%)
#
# Model Improved. Saving the Model...
#
# Epoch: 136
# Train Loss: 0.604353 Acc: 0.6525
# Elapsed 29712.67s, 216.88 s/epoch, 0.36 s/batch, ets 57039.64s
#
# Test set: Average loss: 0.5821, Accuracy: 391/600 (65%)
#
# Epoch: 137
# Train Loss: 0.616143 Acc: 0.6671
# Elapsed 29928.51s, 216.87 s/epoch, 0.36 s/batch, ets 56820.80s
#
# Test set: Average loss: 0.6169, Accuracy: 407/600 (68%)
#
# Epoch: 138
# Train Loss: 0.594951 Acc: 0.6725
# Elapsed 30144.36s, 216.87 s/epoch, 0.36 s/batch, ets 56602.01s
#
# Test set: Average loss: 0.5775, Accuracy: 398/600 (66%)
#
# Epoch: 139
# Train Loss: 0.624916 Acc: 0.6650
# Elapsed 30360.23s, 216.86 s/epoch, 0.36 s/batch, ets 56383.28s
#
# Test set: Average loss: 0.5747, Accuracy: 420/600 (70%)
#
# Epoch: 140
# Train Loss: 0.611097 Acc: 0.6863
# Elapsed 30575.89s, 216.85 s/epoch, 0.36 s/batch, ets 56164.22s
#
# Test set: Average loss: 0.5674, Accuracy: 423/600 (70%)
#
# Model Improved. Saving the Model...
#
# Epoch: 141
# Train Loss: 0.625571 Acc: 0.6392
# Elapsed 30800.57s, 216.91 s/epoch, 0.36 s/batch, ets 55961.60s
#
# Test set: Average loss: 0.5655, Accuracy: 404/600 (67%)
#
# Model Improved. Saving the Model...
#
# Epoch: 142
# Train Loss: 0.584868 Acc: 0.6708
# Elapsed 31025.46s, 216.96 s/epoch, 0.36 s/batch, ets 55759.05s
#
# Test set: Average loss: 0.5798, Accuracy: 412/600 (69%)
#
# Epoch: 143
# Train Loss: 0.607038 Acc: 0.6796
# Elapsed 31241.11s, 216.95 s/epoch, 0.36 s/batch, ets 55539.75s
#
# Test set: Average loss: 0.5548, Accuracy: 434/600 (72%)
#
# Model Improved. Saving the Model...
#
# Epoch: 144
# Train Loss: 0.599125 Acc: 0.6733
# Elapsed 31465.49s, 217.00 s/epoch, 0.36 s/batch, ets 55335.87s
#
# Test set: Average loss: 0.6006, Accuracy: 409/600 (68%)
#
# Epoch: 145
# Train Loss: 0.603659 Acc: 0.6579
# Elapsed 31681.17s, 216.99 s/epoch, 0.36 s/batch, ets 55116.55s
#
# Test set: Average loss: 0.5914, Accuracy: 386/600 (64%)
#
# Epoch: 146
# Train Loss: 0.595249 Acc: 0.6729
# Elapsed 31896.83s, 216.99 s/epoch, 0.36 s/batch, ets 54897.27s
#
# Test set: Average loss: 0.6079, Accuracy: 434/600 (72%)
#
# Epoch: 147
# Train Loss: 0.609710 Acc: 0.6646
# Elapsed 32112.52s, 216.98 s/epoch, 0.36 s/batch, ets 54678.07s
#
# Test set: Average loss: 0.6217, Accuracy: 431/600 (72%)
#
# Epoch: 148
# Train Loss: 0.591214 Acc: 0.6817
# Elapsed 32328.22s, 216.97 s/epoch, 0.36 s/batch, ets 54458.95s
#
# Test set: Average loss: 0.5814, Accuracy: 404/600 (67%)
#
# Epoch: 149
# Train Loss: 0.604837 Acc: 0.6763
# Elapsed 32543.86s, 216.96 s/epoch, 0.36 s/batch, ets 54239.77s
#
# Test set: Average loss: 0.5686, Accuracy: 428/600 (71%)
#
# Epoch: 150
# Train Loss: 0.598653 Acc: 0.6800
# Elapsed 32759.55s, 216.95 s/epoch, 0.36 s/batch, ets 54020.72s
#
# Test set: Average loss: 0.5493, Accuracy: 435/600 (72%)
#
# Model Improved. Saving the Model...
#
# Epoch: 151
# Train Loss: 0.610637 Acc: 0.6654
# Elapsed 32983.59s, 217.00 s/epoch, 0.36 s/batch, ets 53815.33s
#
# Test set: Average loss: 0.5871, Accuracy: 404/600 (67%)
#
# Epoch: 152
# Train Loss: 0.633443 Acc: 0.6575
# Elapsed 33199.44s, 216.99 s/epoch, 0.36 s/batch, ets 53596.47s
#
# Test set: Average loss: 0.5804, Accuracy: 416/600 (69%)
#
# Epoch: 153
# Train Loss: 0.603048 Acc: 0.6546
# Elapsed 33415.27s, 216.98 s/epoch, 0.36 s/batch, ets 53377.65s
#
# Test set: Average loss: 0.5796, Accuracy: 420/600 (70%)
#
# Epoch: 154
# Train Loss: 0.602466 Acc: 0.6592
# Elapsed 33631.11s, 216.97 s/epoch, 0.36 s/batch, ets 53158.85s
#
# Test set: Average loss: 0.5673, Accuracy: 422/600 (70%)
#
# Epoch: 155
# Train Loss: 0.598558 Acc: 0.6621
# Elapsed 33846.97s, 216.97 s/epoch, 0.36 s/batch, ets 52940.13s
#
# Test set: Average loss: 0.5859, Accuracy: 424/600 (71%)
#
# Epoch: 156
# Train Loss: 0.607695 Acc: 0.6879
# Elapsed 34062.82s, 216.96 s/epoch, 0.36 s/batch, ets 52721.44s
#
# Test set: Average loss: 0.5812, Accuracy: 428/600 (71%)
#
# Epoch: 157
# Train Loss: 0.588635 Acc: 0.6796
# Elapsed 34278.83s, 216.95 s/epoch, 0.36 s/batch, ets 52503.01s
#
# Test set: Average loss: 0.5743, Accuracy: 406/600 (68%)
#
# Epoch: 158
# Train Loss: 0.622884 Acc: 0.6525
# Elapsed 34494.69s, 216.95 s/epoch, 0.36 s/batch, ets 52284.41s
#
# Test set: Average loss: 0.5813, Accuracy: 401/600 (67%)
#
# Epoch: 159
# Train Loss: 0.624154 Acc: 0.6587
# Elapsed 34710.50s, 216.94 s/epoch, 0.36 s/batch, ets 52065.75s
#
# Test set: Average loss: 0.5740, Accuracy: 427/600 (71%)
#
# Epoch: 160
# Train Loss: 0.619502 Acc: 0.6579
# Elapsed 34926.32s, 216.93 s/epoch, 0.36 s/batch, ets 51847.15s
#
# Test set: Average loss: 0.5916, Accuracy: 391/600 (65%)
#
# Epoch: 161
# Train Loss: 0.603044 Acc: 0.6604
# Elapsed 35142.16s, 216.93 s/epoch, 0.36 s/batch, ets 51628.61s
#
# Test set: Average loss: 0.5798, Accuracy: 406/600 (68%)
#
# Epoch: 162
# Train Loss: 0.591363 Acc: 0.6671
# Elapsed 35358.02s, 216.92 s/epoch, 0.36 s/batch, ets 51410.12s
#
# Test set: Average loss: 0.5832, Accuracy: 391/600 (65%)
#
# Epoch: 163
# Train Loss: 0.594163 Acc: 0.6733
# Elapsed 35573.85s, 216.91 s/epoch, 0.36 s/batch, ets 51191.64s
#
# Test set: Average loss: 0.5655, Accuracy: 406/600 (68%)
#
# Epoch: 164
# Train Loss: 0.590637 Acc: 0.6529
# Elapsed 35789.71s, 216.91 s/epoch, 0.36 s/batch, ets 50973.23s
#
# Test set: Average loss: 0.5970, Accuracy: 408/600 (68%)
#
# Epoch: 165
# Train Loss: 0.595102 Acc: 0.6813
# Elapsed 36005.57s, 216.90 s/epoch, 0.36 s/batch, ets 50754.84s
#
# Test set: Average loss: 0.5775, Accuracy: 431/600 (72%)
#
# Epoch: 166
# Train Loss: 0.604441 Acc: 0.6663
# Elapsed 36221.39s, 216.89 s/epoch, 0.36 s/batch, ets 50536.43s
#
# Test set: Average loss: 0.5784, Accuracy: 434/600 (72%)
#
# Epoch: 167
# Train Loss: 0.595249 Acc: 0.6725
# Elapsed 36437.24s, 216.89 s/epoch, 0.36 s/batch, ets 50318.09s
#
# Test set: Average loss: 0.6025, Accuracy: 409/600 (68%)
#
# Epoch: 168
# Train Loss: 0.600276 Acc: 0.6663
# Elapsed 36653.25s, 216.88 s/epoch, 0.36 s/batch, ets 50100.01s
#
# Test set: Average loss: 0.5876, Accuracy: 404/600 (67%)
#
# Epoch: 170
# Train Loss: 0.591009 Acc: 0.6829
# Elapsed 37084.93s, 216.87 s/epoch, 0.36 s/batch, ets 49663.45s
#
# Test set: Average loss: 0.5740, Accuracy: 432/600 (72%)
#
# Epoch: 171
# Train Loss: 0.598447 Acc: 0.6667
# Elapsed 37300.77s, 216.86 s/epoch, 0.36 s/batch, ets 49445.21s
#
# Test set: Average loss: 0.5856, Accuracy: 436/600 (73%)
#
# Epoch: 172
# Train Loss: 0.625103 Acc: 0.6546
# Elapsed 37516.61s, 216.86 s/epoch, 0.36 s/batch, ets 49226.99s
#
# Test set: Average loss: 0.5559, Accuracy: 427/600 (71%)
#
# Epoch: 173
# Train Loss: 0.577691 Acc: 0.6975
# Elapsed 37732.47s, 216.85 s/epoch, 0.36 s/batch, ets 49008.84s
#
# Test set: Average loss: 0.5731, Accuracy: 412/600 (69%)
#
# Epoch: 174
# Train Loss: 0.579810 Acc: 0.6842
# Elapsed 37948.30s, 216.85 s/epoch, 0.36 s/batch, ets 48790.67s
#
# Test set: Average loss: 0.5760, Accuracy: 415/600 (69%)
#
# Epoch: 175
# Train Loss: 0.602939 Acc: 0.6675
# Elapsed 38164.13s, 216.84 s/epoch, 0.36 s/batch, ets 48572.53s
#
# Test set: Average loss: 0.5724, Accuracy: 431/600 (72%)
#
# Epoch: 176
# Train Loss: 0.596274 Acc: 0.6675
# Elapsed 38379.83s, 216.84 s/epoch, 0.36 s/batch, ets 48354.25s
#
# Test set: Average loss: 0.5822, Accuracy: 441/600 (74%)
#
# Epoch: 177
# Train Loss: 0.587852 Acc: 0.6792
# Elapsed 38595.69s, 216.83 s/epoch, 0.36 s/batch, ets 48136.19s
#
# Test set: Average loss: 0.5993, Accuracy: 421/600 (70%)
#
# Epoch: 178
# Train Loss: 0.592262 Acc: 0.6800
# Elapsed 38811.54s, 216.82 s/epoch, 0.36 s/batch, ets 47918.16s
#
# Test set: Average loss: 0.5681, Accuracy: 441/600 (74%)
#
# Epoch: 179
# Train Loss: 0.589692 Acc: 0.6854
# Elapsed 39027.21s, 216.82 s/epoch, 0.36 s/batch, ets 47699.92s
#
# Test set: Average loss: 0.5713, Accuracy: 412/600 (69%)
#
# Epoch: 180
# Train Loss: 0.595407 Acc: 0.6854
# Elapsed 39242.89s, 216.81 s/epoch, 0.36 s/batch, ets 47481.73s
#
# Test set: Average loss: 0.5733, Accuracy: 427/600 (71%)
#
# Epoch: 181
# Train Loss: 0.592949 Acc: 0.6863
# Elapsed 39458.72s, 216.81 s/epoch, 0.36 s/batch, ets 47263.74s
#
# Test set: Average loss: 0.5826, Accuracy: 428/600 (71%)
#
# Epoch: 182
# Train Loss: 0.585294 Acc: 0.6829
# Elapsed 39674.58s, 216.80 s/epoch, 0.36 s/batch, ets 47045.81s
#
# Test set: Average loss: 0.5574, Accuracy: 436/600 (73%)
#
# Epoch: 183
# Train Loss: 0.592999 Acc: 0.6742
# Elapsed 39890.42s, 216.80 s/epoch, 0.36 s/batch, ets 46827.88s
#
# Test set: Average loss: 0.5942, Accuracy: 418/600 (70%)
#
# Epoch: 184
# Train Loss: 0.603750 Acc: 0.6725
# Elapsed 40106.27s, 216.79 s/epoch, 0.36 s/batch, ets 46609.99s
#
# Test set: Average loss: 0.6156, Accuracy: 398/600 (66%)
#
# Epoch: 185
# Train Loss: 0.590739 Acc: 0.6850
# Elapsed 40322.11s, 216.79 s/epoch, 0.36 s/batch, ets 46392.11s
#
# Test set: Average loss: 0.5496, Accuracy: 423/600 (70%)
#
# Epoch: 186
# Train Loss: 0.588062 Acc: 0.6792
# Elapsed 40537.96s, 216.78 s/epoch, 0.36 s/batch, ets 46174.26s
#
# Test set: Average loss: 0.5493, Accuracy: 428/600 (71%)
#
# Epoch: 187
# Train Loss: 0.617327 Acc: 0.6546
# Elapsed 40753.81s, 216.78 s/epoch, 0.36 s/batch, ets 45956.42s
#
# Test set: Average loss: 0.5642, Accuracy: 440/600 (73%)
#
# Epoch: 188
# Train Loss: 0.603508 Acc: 0.6700
# Elapsed 40969.67s, 216.77 s/epoch, 0.36 s/batch, ets 45738.63s
#
# Test set: Average loss: 0.5757, Accuracy: 388/600 (65%)
#
# Epoch: 189
# Train Loss: 0.596298 Acc: 0.6533
# Elapsed 41185.53s, 216.77 s/epoch, 0.36 s/batch, ets 45520.85s
#
# Test set: Average loss: 0.5691, Accuracy: 424/600 (71%)
#
# Epoch: 190
# Train Loss: 0.592892 Acc: 0.6829
# Elapsed 41401.39s, 216.76 s/epoch, 0.36 s/batch, ets 45303.09s
#
# Test set: Average loss: 0.5596, Accuracy: 434/600 (72%)
#
# Epoch: 191
# Train Loss: 0.589961 Acc: 0.6863
# Elapsed 41617.24s, 216.76 s/epoch, 0.36 s/batch, ets 45085.35s
#
# Test set: Average loss: 0.5820, Accuracy: 385/600 (64%)
#
# Epoch: 192
# Train Loss: 0.603565 Acc: 0.6642
# Elapsed 41833.08s, 216.75 s/epoch, 0.36 s/batch, ets 44867.60s
#
# Test set: Average loss: 0.5692, Accuracy: 427/600 (71%)
#
# Epoch: 193
# Train Loss: 0.599969 Acc: 0.6817
# Elapsed 42048.90s, 216.75 s/epoch, 0.36 s/batch, ets 44649.87s
#
# Test set: Average loss: 0.5827, Accuracy: 402/600 (67%)
#
# Epoch: 194
# Train Loss: 0.592368 Acc: 0.6763
# Elapsed 42264.76s, 216.74 s/epoch, 0.36 s/batch, ets 44432.18s
#
# Test set: Average loss: 0.5931, Accuracy: 414/600 (69%)
#
# Epoch: 195
# Train Loss: 0.599572 Acc: 0.6758
# Elapsed 42480.43s, 216.74 s/epoch, 0.36 s/batch, ets 44214.32s
#
# Test set: Average loss: 0.5870, Accuracy: 419/600 (70%)
#
# Epoch: 196
# Train Loss: 0.580283 Acc: 0.6842
# Elapsed 42696.26s, 216.73 s/epoch, 0.36 s/batch, ets 43996.65s
#
# Test set: Average loss: 0.5754, Accuracy: 430/600 (72%)
#
# Epoch: 197
# Train Loss: 0.588870 Acc: 0.6796
# Elapsed 42912.12s, 216.73 s/epoch, 0.36 s/batch, ets 43779.03s
#
# Test set: Average loss: 0.5653, Accuracy: 414/600 (69%)
#
# Epoch: 198
# Train Loss: 0.595135 Acc: 0.6767
# Elapsed 43127.93s, 216.72 s/epoch, 0.36 s/batch, ets 43561.38s
#
# Test set: Average loss: 0.5501, Accuracy: 436/600 (73%)
#
# Epoch: 199
# Train Loss: 0.590610 Acc: 0.6800
# Elapsed 43343.77s, 216.72 s/epoch, 0.36 s/batch, ets 43343.77s
#
# Test set: Average loss: 0.5732, Accuracy: 442/600 (74%)
#
# Epoch: 200
# Train Loss: 0.584517 Acc: 0.6754
# Elapsed 43559.62s, 216.71 s/epoch, 0.36 s/batch, ets 43126.20s
#
# Test set: Average loss: 0.5834, Accuracy: 443/600 (74%)
#
# Epoch: 201
# Train Loss: 0.582176 Acc: 0.6896
# Elapsed 43775.44s, 216.71 s/epoch, 0.36 s/batch, ets 42908.60s
#
# Test set: Average loss: 0.5797, Accuracy: 411/600 (68%)
#
# Epoch: 202
# Train Loss: 0.578929 Acc: 0.6963
# Elapsed 43991.30s, 216.71 s/epoch, 0.36 s/batch, ets 42691.07s
#
# Test set: Average loss: 0.5594, Accuracy: 423/600 (70%)
#
# Epoch: 203
# Train Loss: 0.593829 Acc: 0.6804
# Elapsed 44207.14s, 216.70 s/epoch, 0.36 s/batch, ets 42473.53s
#
# Test set: Average loss: 0.6335, Accuracy: 424/600 (71%)
#
# Epoch: 204
# Train Loss: 0.630203 Acc: 0.6775
# Elapsed 44423.00s, 216.70 s/epoch, 0.36 s/batch, ets 42256.02s
#
# Test set: Average loss: 0.5667, Accuracy: 439/600 (73%)
#
# Epoch: 205
# Train Loss: 0.580146 Acc: 0.6825
# Elapsed 44638.83s, 216.69 s/epoch, 0.36 s/batch, ets 42038.51s
#
# Test set: Average loss: 0.5797, Accuracy: 414/600 (69%)
#
# Epoch: 206
# Train Loss: 0.573553 Acc: 0.6908
# Elapsed 44854.70s, 216.69 s/epoch, 0.36 s/batch, ets 41821.05s
#
# Test set: Average loss: 0.5380, Accuracy: 441/600 (74%)
#
# Model Improved. Saving the Model...
#
# Epoch: 207
# Train Loss: 0.574461 Acc: 0.6896
# Elapsed 45078.72s, 216.72 s/epoch, 0.36 s/batch, ets 41611.12s
#
# Test set: Average loss: 0.5455, Accuracy: 423/600 (70%)
#
# Epoch: 208
# Train Loss: 0.597699 Acc: 0.6875
# Elapsed 45294.59s, 216.72 s/epoch, 0.36 s/batch, ets 41393.62s
#
# Test set: Average loss: 0.5474, Accuracy: 440/600 (73%)
#
# Epoch: 209
# Train Loss: 0.601293 Acc: 0.6779
# Elapsed 45510.44s, 216.72 s/epoch, 0.36 s/batch, ets 41176.12s
#
# Test set: Average loss: 0.5730, Accuracy: 430/600 (72%)
#
# Epoch: 210
# Train Loss: 0.578556 Acc: 0.6879
# Elapsed 45726.28s, 216.71 s/epoch, 0.36 s/batch, ets 40958.61s
#
# Test set: Average loss: 0.5605, Accuracy: 439/600 (73%)
#
# Epoch: 211
# Train Loss: 0.586767 Acc: 0.6821
# Elapsed 45942.11s, 216.71 s/epoch, 0.36 s/batch, ets 40741.12s
#
# Test set: Average loss: 0.5527, Accuracy: 442/600 (74%)
#
# Epoch: 212
# Train Loss: 0.581263 Acc: 0.6858
# Elapsed 46157.95s, 216.70 s/epoch, 0.36 s/batch, ets 40523.64s
#
# Test set: Average loss: 0.5647, Accuracy: 427/600 (71%)
#
# Epoch: 213
# Train Loss: 0.586428 Acc: 0.6875
# Elapsed 46373.80s, 216.70 s/epoch, 0.36 s/batch, ets 40306.20s
#
# Test set: Average loss: 0.5631, Accuracy: 422/600 (70%)
#
# Epoch: 214
# Train Loss: 0.574776 Acc: 0.6896
# Elapsed 46589.48s, 216.70 s/epoch, 0.36 s/batch, ets 40088.62s
#
# Test set: Average loss: 0.5687, Accuracy: 441/600 (74%)
#
# Epoch: 215
# Train Loss: 0.580580 Acc: 0.6800
# Elapsed 46805.32s, 216.69 s/epoch, 0.36 s/batch, ets 39871.20s
#
# Test set: Average loss: 0.5528, Accuracy: 419/600 (70%)
#
# Epoch: 216
# Train Loss: 0.574987 Acc: 0.6846
# Elapsed 47021.16s, 216.69 s/epoch, 0.36 s/batch, ets 39653.79s
#
# Test set: Average loss: 0.5734, Accuracy: 450/600 (75%)
#
# Epoch: 217
# Train Loss: 0.578928 Acc: 0.6754
# Elapsed 47237.02s, 216.68 s/epoch, 0.36 s/batch, ets 39436.41s
#
# Test set: Average loss: 0.5909, Accuracy: 401/600 (67%)
#
# Epoch: 218
# Train Loss: 0.583040 Acc: 0.6800
# Elapsed 47452.86s, 216.68 s/epoch, 0.36 s/batch, ets 39219.03s
#
# Test set: Average loss: 0.5718, Accuracy: 426/600 (71%)
#
# Epoch: 219
# Train Loss: 0.595940 Acc: 0.6642
# Elapsed 47668.71s, 216.68 s/epoch, 0.36 s/batch, ets 39001.67s
#
# Test set: Average loss: 0.5966, Accuracy: 425/600 (71%)
#
# Epoch: 220
# Train Loss: 0.580954 Acc: 0.6904
# Elapsed 47884.57s, 216.67 s/epoch, 0.36 s/batch, ets 38784.34s
#
# Test set: Average loss: 0.5352, Accuracy: 453/600 (76%)
#
# Model Improved. Saving the Model...
#
# Epoch: 221
# Train Loss: 0.583355 Acc: 0.6942
# Elapsed 48109.30s, 216.71 s/epoch, 0.36 s/batch, ets 38574.12s
#
# Test set: Average loss: 0.5478, Accuracy: 442/600 (74%)
#
# Epoch: 222
# Train Loss: 0.583733 Acc: 0.6875
# Elapsed 48325.14s, 216.70 s/epoch, 0.36 s/batch, ets 38356.72s
#
# Test set: Average loss: 0.5667, Accuracy: 430/600 (72%)
#
# Epoch: 223
# Train Loss: 0.572441 Acc: 0.6963
# Elapsed 48541.00s, 216.70 s/epoch, 0.36 s/batch, ets 38139.35s
#
# Test set: Average loss: 0.5395, Accuracy: 441/600 (74%)
#
# Epoch: 224
# Train Loss: 0.591945 Acc: 0.6825
# Elapsed 48756.84s, 216.70 s/epoch, 0.36 s/batch, ets 37921.99s
#
# Test set: Average loss: 0.5473, Accuracy: 447/600 (74%)
#
# Epoch: 225
# Train Loss: 0.597787 Acc: 0.6754
# Elapsed 48972.86s, 216.69 s/epoch, 0.36 s/batch, ets 37704.77s
#
# Test set: Average loss: 0.5649, Accuracy: 433/600 (72%)
#
# Epoch: 226
# Train Loss: 0.596689 Acc: 0.6871
# Elapsed 49188.72s, 216.69 s/epoch, 0.36 s/batch, ets 37487.44s
#
# Test set: Average loss: 0.5413, Accuracy: 463/600 (77%)
#
# Epoch: 227
# Train Loss: 0.573120 Acc: 0.7025
# Elapsed 49404.54s, 216.69 s/epoch, 0.36 s/batch, ets 37270.09s
#
# Test set: Average loss: 0.5351, Accuracy: 458/600 (76%)
#
# Model Improved. Saving the Model...
#
# Epoch: 228
# Train Loss: 0.586928 Acc: 0.7029
# Elapsed 49628.57s, 216.72 s/epoch, 0.36 s/batch, ets 37058.89s
#
# Test set: Average loss: 0.5276, Accuracy: 439/600 (73%)
#
# Model Improved. Saving the Model...
#
# Epoch: 229
# Train Loss: 0.569097 Acc: 0.6746
# Elapsed 49853.28s, 216.75 s/epoch, 0.36 s/batch, ets 36848.07s
#
# Test set: Average loss: 0.5463, Accuracy: 448/600 (75%)
#
# Epoch: 230
# Train Loss: 0.567001 Acc: 0.6904
# Elapsed 50068.96s, 216.75 s/epoch, 0.36 s/batch, ets 36630.54s
#
# Test set: Average loss: 0.5396, Accuracy: 450/600 (75%)
#
# Epoch: 231
# Train Loss: 0.579749 Acc: 0.6892
# Elapsed 50284.80s, 216.74 s/epoch, 0.36 s/batch, ets 36413.13s
#
# Test set: Average loss: 0.5465, Accuracy: 438/600 (73%)
#
# Epoch: 232
# Train Loss: 0.574396 Acc: 0.6896
# Elapsed 50500.63s, 216.74 s/epoch, 0.36 s/batch, ets 36195.73s
#
# Test set: Average loss: 0.5621, Accuracy: 434/600 (72%)
#
# Epoch: 233
# Train Loss: 0.573751 Acc: 0.7013
# Elapsed 50716.49s, 216.74 s/epoch, 0.36 s/batch, ets 35978.37s
#
# Test set: Average loss: 0.5347, Accuracy: 444/600 (74%)
#
# Epoch: 234
# Train Loss: 0.567062 Acc: 0.7000
# Elapsed 50932.32s, 216.73 s/epoch, 0.36 s/batch, ets 35760.99s
#
# Test set: Average loss: 0.5353, Accuracy: 458/600 (76%)
#
# Epoch: 235
# Train Loss: 0.548566 Acc: 0.7108
# Elapsed 51148.18s, 216.73 s/epoch, 0.36 s/batch, ets 35543.65s
#
# Test set: Average loss: 0.5339, Accuracy: 442/600 (74%)
#
# Epoch: 236
# Train Loss: 0.559108 Acc: 0.7046
# Elapsed 51364.03s, 216.73 s/epoch, 0.36 s/batch, ets 35326.32s
#
# Test set: Average loss: 0.5495, Accuracy: 436/600 (73%)
#
# Epoch: 237
# Train Loss: 0.587972 Acc: 0.6925
# Elapsed 51579.89s, 216.72 s/epoch, 0.36 s/batch, ets 35109.00s
#
# Test set: Average loss: 0.5280, Accuracy: 444/600 (74%)
#
# Epoch: 238
# Train Loss: 0.558772 Acc: 0.6987
# Elapsed 51795.74s, 216.72 s/epoch, 0.36 s/batch, ets 34891.69s
#
# Test set: Average loss: 0.5282, Accuracy: 460/600 (77%)
#
# Epoch: 239
# Train Loss: 0.576000 Acc: 0.6946
# Elapsed 52011.62s, 216.72 s/epoch, 0.36 s/batch, ets 34674.42s
#
# Test set: Average loss: 0.5276, Accuracy: 458/600 (76%)
#
# Epoch: 240
# Train Loss: 0.582174 Acc: 0.6858
# Elapsed 52227.48s, 216.71 s/epoch, 0.36 s/batch, ets 34457.13s
#
# Test set: Average loss: 0.5329, Accuracy: 427/600 (71%)
#
# Epoch: 241
# Train Loss: 0.580239 Acc: 0.6863
# Elapsed 52443.32s, 216.71 s/epoch, 0.36 s/batch, ets 34239.85s
#
# Test set: Average loss: 0.5308, Accuracy: 445/600 (74%)
#
# Epoch: 242
# Train Loss: 0.579910 Acc: 0.6846
# Elapsed 52659.17s, 216.70 s/epoch, 0.36 s/batch, ets 34022.59s
#
# Test set: Average loss: 0.5438, Accuracy: 433/600 (72%)
#
# Epoch: 243
# Train Loss: 0.568230 Acc: 0.6858
# Elapsed 52875.02s, 216.70 s/epoch, 0.36 s/batch, ets 33805.34s
#
# Test set: Average loss: 0.5245, Accuracy: 435/600 (72%)
#
# Model Improved. Saving the Model...
#
# Epoch: 244
# Train Loss: 0.566737 Acc: 0.6967
# Elapsed 53099.21s, 216.73 s/epoch, 0.36 s/batch, ets 33593.38s
#
# Test set: Average loss: 0.5311, Accuracy: 468/600 (78%)
#
# Epoch: 245
# Train Loss: 0.563178 Acc: 0.7042
# Elapsed 53314.86s, 216.73 s/epoch, 0.36 s/batch, ets 33375.97s
#
# Test set: Average loss: 0.5336, Accuracy: 456/600 (76%)
#
# Epoch: 246
# Train Loss: 0.585449 Acc: 0.6858
# Elapsed 53530.70s, 216.72 s/epoch, 0.36 s/batch, ets 33158.69s
#
# Test set: Average loss: 0.5514, Accuracy: 450/600 (75%)
#
# Epoch: 247
# Train Loss: 0.569574 Acc: 0.7021
# Elapsed 53747.06s, 216.72 s/epoch, 0.36 s/batch, ets 32941.75s
#
# Test set: Average loss: 0.5337, Accuracy: 459/600 (76%)
#
# Epoch: 248
# Train Loss: 0.567966 Acc: 0.7137
# Elapsed 53963.08s, 216.72 s/epoch, 0.36 s/batch, ets 32724.60s
#
# Test set: Average loss: 0.5297, Accuracy: 458/600 (76%)
#
# Epoch: 249
# Train Loss: 0.587266 Acc: 0.6937
# Elapsed 54178.92s, 216.72 s/epoch, 0.36 s/batch, ets 32507.35s
#
# Test set: Average loss: 0.5391, Accuracy: 433/600 (72%)
#
# Epoch: 250
# Train Loss: 0.565403 Acc: 0.7021
# Elapsed 54394.78s, 216.71 s/epoch, 0.36 s/batch, ets 32290.13s
#
# Test set: Average loss: 0.5327, Accuracy: 437/600 (73%)
#
# Epoch: 251
# Train Loss: 0.561083 Acc: 0.6896
# Elapsed 54610.62s, 216.71 s/epoch, 0.36 s/batch, ets 32072.90s
#
# Test set: Average loss: 0.5469, Accuracy: 409/600 (68%)
#
# Epoch: 252
# Train Loss: 0.579658 Acc: 0.6900
# Elapsed 54826.45s, 216.71 s/epoch, 0.36 s/batch, ets 31855.68s
#
# Test set: Average loss: 0.5379, Accuracy: 445/600 (74%)
#
# Epoch: 253
# Train Loss: 0.575998 Acc: 0.6979
# Elapsed 55042.29s, 216.70 s/epoch, 0.36 s/batch, ets 31638.48s
#
# Test set: Average loss: 0.5535, Accuracy: 439/600 (73%)
#
# Epoch: 254
# Train Loss: 0.578293 Acc: 0.6917
# Elapsed 55257.97s, 216.70 s/epoch, 0.36 s/batch, ets 31421.20s
#
# Test set: Average loss: 0.5239, Accuracy: 455/600 (76%)
#
# Model Improved. Saving the Model...
#
# Epoch: 255
# Train Loss: 0.563708 Acc: 0.6896
# Elapsed 55482.01s, 216.73 s/epoch, 0.36 s/batch, ets 31208.63s
#
# Test set: Average loss: 0.5504, Accuracy: 467/600 (78%)
#
# Epoch: 256
# Train Loss: 0.582889 Acc: 0.7008
# Elapsed 55697.86s, 216.72 s/epoch, 0.36 s/batch, ets 30991.42s
#
# Test set: Average loss: 0.5277, Accuracy: 456/600 (76%)
#
# Epoch: 257
# Train Loss: 0.571397 Acc: 0.6950
# Elapsed 55913.71s, 216.72 s/epoch, 0.36 s/batch, ets 30774.21s
#
# Test set: Average loss: 0.5218, Accuracy: 459/600 (76%)
#
# Model Improved. Saving the Model...
#
# Epoch: 258
# Train Loss: 0.551352 Acc: 0.7058
# Elapsed 56138.75s, 216.75 s/epoch, 0.36 s/batch, ets 30562.02s
#
# Test set: Average loss: 0.5196, Accuracy: 462/600 (77%)
#
# Model Improved. Saving the Model...
#
# Epoch: 259
# Train Loss: 0.556064 Acc: 0.6963
# Elapsed 56366.87s, 216.80 s/epoch, 0.36 s/batch, ets 30351.39s
#
# Test set: Average loss: 0.5293, Accuracy: 443/600 (74%)
#
# Epoch: 260
# Train Loss: 0.564296 Acc: 0.6942
# Elapsed 56583.25s, 216.79 s/epoch, 0.36 s/batch, ets 30134.38s
#
# Test set: Average loss: 0.5148, Accuracy: 459/600 (76%)
#
# Model Improved. Saving the Model...
#
# Epoch: 261
# Train Loss: 0.559417 Acc: 0.6979
# Elapsed 56808.34s, 216.83 s/epoch, 0.36 s/batch, ets 29921.95s
#
# Test set: Average loss: 0.5109, Accuracy: 465/600 (78%)
#
# Model Improved. Saving the Model...
#
# Epoch: 262
# Train Loss: 0.599145 Acc: 0.6792
# Elapsed 57033.19s, 216.86 s/epoch, 0.36 s/batch, ets 29709.31s
#
# Test set: Average loss: 0.5313, Accuracy: 449/600 (75%)
#
# Epoch: 263
# Train Loss: 0.559319 Acc: 0.7117
# Elapsed 57249.04s, 216.85 s/epoch, 0.36 s/batch, ets 29491.93s
#
# Test set: Average loss: 0.5160, Accuracy: 444/600 (74%)
#
# Epoch: 264
# Train Loss: 0.573984 Acc: 0.6913
# Elapsed 57464.75s, 216.85 s/epoch, 0.36 s/batch, ets 29274.50s
#
# Test set: Average loss: 0.5314, Accuracy: 453/600 (76%)
#
# Epoch: 265
# Train Loss: 0.566001 Acc: 0.7079
# Elapsed 57680.57s, 216.84 s/epoch, 0.36 s/batch, ets 29057.13s
#
# Test set: Average loss: 0.5088, Accuracy: 469/600 (78%)
#
# Model Improved. Saving the Model...
#
# Epoch: 266
# Train Loss: 0.553607 Acc: 0.7087
# Elapsed 57905.66s, 216.88 s/epoch, 0.36 s/batch, ets 28844.39s
#
# Test set: Average loss: 0.5225, Accuracy: 465/600 (78%)
#
# Epoch: 267
# Train Loss: 0.557263 Acc: 0.6900
# Elapsed 58121.51s, 216.87 s/epoch, 0.36 s/batch, ets 28627.01s
#
# Test set: Average loss: 0.5139, Accuracy: 476/600 (79%)
#
# Epoch: 268
# Train Loss: 0.537876 Acc: 0.7133
# Elapsed 58337.38s, 216.87 s/epoch, 0.36 s/batch, ets 28409.65s
#
# Test set: Average loss: 0.5009, Accuracy: 461/600 (77%)
#
# Model Improved. Saving the Model...
#
# Epoch: 269
# Train Loss: 0.564408 Acc: 0.7008
# Elapsed 58562.61s, 216.90 s/epoch, 0.36 s/batch, ets 28196.81s
#
# Test set: Average loss: 0.5226, Accuracy: 450/600 (75%)
#
# Epoch: 270
# Train Loss: 0.557087 Acc: 0.6983
# Elapsed 58778.46s, 216.89 s/epoch, 0.36 s/batch, ets 27979.42s
#
# Test set: Average loss: 0.5288, Accuracy: 437/600 (73%)
#
# Epoch: 271
# Train Loss: 0.573356 Acc: 0.7021
# Elapsed 58994.34s, 216.89 s/epoch, 0.36 s/batch, ets 27762.04s
#
# Test set: Average loss: 0.5116, Accuracy: 465/600 (78%)
#
# Epoch: 272
# Train Loss: 0.551681 Acc: 0.7021
# Elapsed 59210.18s, 216.89 s/epoch, 0.36 s/batch, ets 27544.66s
#
# Test set: Average loss: 0.5141, Accuracy: 426/600 (71%)
#
# Epoch: 273
# Train Loss: 0.570922 Acc: 0.7042
# Elapsed 59426.03s, 216.88 s/epoch, 0.36 s/batch, ets 27327.30s
#
# Test set: Average loss: 0.5123, Accuracy: 465/600 (78%)
#
# Epoch: 274
# Train Loss: 0.580892 Acc: 0.7033
# Elapsed 59641.88s, 216.88 s/epoch, 0.36 s/batch, ets 27109.95s
#
# Test set: Average loss: 0.5079, Accuracy: 463/600 (77%)
#
# Epoch: 275
# Train Loss: 0.552687 Acc: 0.7029
# Elapsed 59857.72s, 216.88 s/epoch, 0.36 s/batch, ets 26892.60s
#
# Test set: Average loss: 0.5129, Accuracy: 451/600 (75%)
#
# Epoch: 276
# Train Loss: 0.564960 Acc: 0.7121
# Elapsed 60073.58s, 216.87 s/epoch, 0.36 s/batch, ets 26675.27s
#
# Test set: Average loss: 0.5177, Accuracy: 464/600 (77%)
#
# Epoch: 277
# Train Loss: 0.556458 Acc: 0.7037
# Elapsed 60289.58s, 216.87 s/epoch, 0.36 s/batch, ets 26458.02s
#
# Test set: Average loss: 0.5167, Accuracy: 460/600 (77%)
#
# Epoch: 278
# Train Loss: 0.550431 Acc: 0.7154
# Elapsed 60505.62s, 216.87 s/epoch, 0.36 s/batch, ets 26240.79s
#
# Test set: Average loss: 0.5249, Accuracy: 463/600 (77%)
#
# Epoch: 279
# Train Loss: 0.556021 Acc: 0.7050
# Elapsed 60721.46s, 216.86 s/epoch, 0.36 s/batch, ets 26023.48s
#
# Test set: Average loss: 0.5297, Accuracy: 452/600 (75%)
#
# Epoch: 280
# Train Loss: 0.552053 Acc: 0.7117
# Elapsed 60937.31s, 216.86 s/epoch, 0.36 s/batch, ets 25806.19s
#
# Test set: Average loss: 0.5087, Accuracy: 456/600 (76%)
#
# Epoch: 281
# Train Loss: 0.559126 Acc: 0.7000
# Elapsed 61153.15s, 216.86 s/epoch, 0.36 s/batch, ets 25588.91s
#
# Test set: Average loss: 0.5185, Accuracy: 454/600 (76%)
#
# Epoch: 282
# ...
#
# Test set: Average loss: 0.4975, Accuracy: 452/600 (75%)
#
# Epoch: 306
# Train Loss: 0.531318 Acc: 0.7208
# Elapsed 66587.02s, 216.90 s/epoch, 0.36 s/batch, ets 20171.31s
#
# Test set: Average loss: 0.4899, Accuracy: 469/600 (78%)
#
# Epoch: 307
# Train Loss: 0.545695 Acc: 0.7175
# Elapsed 66803.03s, 216.89 s/epoch, 0.36 s/batch, ets 19954.15s
#
# Test set: Average loss: 0.4915, Accuracy: 471/600 (78%)
#
# Epoch: 308
# Train Loss: 0.541314 Acc: 0.7121
# Elapsed 67018.87s, 216.89 s/epoch, 0.36 s/batch, ets 19736.95s
#
# Test set: Average loss: 0.4760, Accuracy: 456/600 (76%)
#
# Model Improved. Saving the Model...
#
# Epoch: 309
# Train Loss: 0.542521 Acc: 0.7229
# Elapsed 67243.40s, 216.91 s/epoch, 0.36 s/batch, ets 19522.28s
#
# Test set: Average loss: 0.4761, Accuracy: 470/600 (78%)
#
# Epoch: 310
# Train Loss: 0.551359 Acc: 0.7175
# Elapsed 67459.25s, 216.91 s/epoch, 0.36 s/batch, ets 19305.06s
#
# Test set: Average loss: 0.5050, Accuracy: 454/600 (76%)
#
# Epoch: 311
# Train Loss: 0.567253 Acc: 0.7046
# Elapsed 67675.09s, 216.91 s/epoch, 0.36 s/batch, ets 19087.85s
#
# Test set: Average loss: 0.4881, Accuracy: 455/600 (76%)
#
# Epoch: 312
# Train Loss: 0.545857 Acc: 0.7167
# Elapsed 67890.92s, 216.90 s/epoch, 0.36 s/batch, ets 18870.64s
#
# Test set: Average loss: 0.4824, Accuracy: 473/600 (79%)
#
# Epoch: 313
# Train Loss: 0.516170 Acc: 0.7338
# Elapsed 68106.78s, 216.90 s/epoch, 0.36 s/batch, ets 18653.45s
#
# Test set: Average loss: 0.4699, Accuracy: 470/600 (78%)
#
# Model Improved. Saving the Model...
#
# Epoch: 314
# Train Loss: 0.541377 Acc: 0.7183
# Elapsed 68331.65s, 216.93 s/epoch, 0.36 s/batch, ets 18438.70s
#
# Test set: Average loss: 0.4893, Accuracy: 456/600 (76%)
#
# Epoch: 315
# Train Loss: 0.546135 Acc: 0.7029
# Elapsed 68547.33s, 216.92 s/epoch, 0.36 s/batch, ets 18221.44s
#
# Test set: Average loss: 0.4770, Accuracy: 465/600 (78%)
#
# Epoch: 316
# Train Loss: 0.532074 Acc: 0.7329
# Elapsed 68763.20s, 216.92 s/epoch, 0.36 s/batch, ets 18004.25s
#
# Test set: Average loss: 0.5048, Accuracy: 456/600 (76%)
#
# Epoch: 317
# Train Loss: 0.542477 Acc: 0.7200
# Elapsed 68979.05s, 216.92 s/epoch, 0.36 s/batch, ets 17787.05s
#
# Test set: Average loss: 0.4752, Accuracy: 475/600 (79%)
#
# Epoch: 318
# Train Loss: 0.534348 Acc: 0.7225
# Elapsed 69194.86s, 216.91 s/epoch, 0.36 s/batch, ets 17569.86s
#
# Test set: Average loss: 0.5097, Accuracy: 451/600 (75%)
#
# Epoch: 319
# Train Loss: 0.542478 Acc: 0.7233
# Elapsed 69410.54s, 216.91 s/epoch, 0.36 s/batch, ets 17352.64s
#
# Test set: Average loss: 0.5024, Accuracy: 460/600 (77%)
#
# Epoch: 320
# Train Loss: 0.546447 Acc: 0.7079
# Elapsed 69626.40s, 216.90 s/epoch, 0.36 s/batch, ets 17135.47s
#
# Test set: Average loss: 0.4868, Accuracy: 477/600 (80%)
#
# Epoch: 321
# Train Loss: 0.533847 Acc: 0.7163
# Elapsed 69842.25s, 216.90 s/epoch, 0.36 s/batch, ets 16918.31s
#
# Test set: Average loss: 0.4806, Accuracy: 472/600 (79%)
#
# Epoch: 322
# Train Loss: 0.547237 Acc: 0.7238
# Elapsed 70058.11s, 216.90 s/epoch, 0.36 s/batch, ets 16701.16s
#
# Test set: Average loss: 0.4660, Accuracy: 482/600 (80%)
#
# Model Improved. Saving the Model...
#
# Epoch: 323
# Train Loss: 0.539671 Acc: 0.7142
# Elapsed 70286.06s, 216.93 s/epoch, 0.36 s/batch, ets 16486.85s
#
# Test set: Average loss: 0.4959, Accuracy: 462/600 (77%)
#
# Epoch: 324
# Train Loss: 0.541938 Acc: 0.7137
# Elapsed 70501.75s, 216.93 s/epoch, 0.36 s/batch, ets 16269.63s
#
# Test set: Average loss: 0.4688, Accuracy: 469/600 (78%)
#
# Epoch: 325
# Train Loss: 0.550977 Acc: 0.7179
# Elapsed 70717.59s, 216.93 s/epoch, 0.36 s/batch, ets 16052.46s
#
# Test set: Average loss: 0.4770, Accuracy: 472/600 (79%)
#
# Epoch: 326
# Train Loss: 0.559230 Acc: 0.6946
# Elapsed 70933.43s, 216.92 s/epoch, 0.36 s/batch, ets 15835.29s
#
# Test set: Average loss: 0.5106, Accuracy: 468/600 (78%)
#
# Epoch: 327
# Train Loss: 0.532333 Acc: 0.7208
# Elapsed 71149.28s, 216.92 s/epoch, 0.36 s/batch, ets 15618.13s
#
# Test set: Average loss: 0.4832, Accuracy: 470/600 (78%)
#
# Epoch: 328
# Train Loss: 0.541975 Acc: 0.7233
# Elapsed 71365.15s, 216.92 s/epoch, 0.36 s/batch, ets 15400.99s
#
# Test set: Average loss: 0.4847, Accuracy: 472/600 (79%)
#
# Epoch: 329
# Train Loss: 0.531351 Acc: 0.7279
# Elapsed 71581.15s, 216.91 s/epoch, 0.36 s/batch, ets 15183.88s
#
# Test set: Average loss: 0.4664, Accuracy: 478/600 (80%)
#
# Epoch: 330
# Train Loss: 0.532404 Acc: 0.7321
# Elapsed 71797.01s, 216.91 s/epoch, 0.36 s/batch, ets 14966.75s
#
# Test set: Average loss: 0.4761, Accuracy: 457/600 (76%)
#
# Epoch: 331
# Train Loss: 0.524491 Acc: 0.7225
# Elapsed 72012.85s, 216.91 s/epoch, 0.36 s/batch, ets 14749.62s
#
# Test set: Average loss: 0.4583, Accuracy: 464/600 (77%)
#
# Model Improved. Saving the Model...
#
# Epoch: 332
# Train Loss: 0.538110 Acc: 0.7087
# Elapsed 72242.14s, 216.94 s/epoch, 0.36 s/batch, ets 14535.21s
#
# Test set: Average loss: 0.4610, Accuracy: 468/600 (78%)
#
# Epoch: 333
# Train Loss: 0.533558 Acc: 0.7275
# Elapsed 72457.86s, 216.94 s/epoch, 0.36 s/batch, ets 14318.02s
#
# Test set: Average loss: 0.4778, Accuracy: 467/600 (78%)
#
# Epoch: 334
# Train Loss: 0.514804 Acc: 0.7371
# Elapsed 72673.70s, 216.94 s/epoch, 0.36 s/batch, ets 14100.87s
#
# Test set: Average loss: 0.4440, Accuracy: 478/600 (80%)
#
# Model Improved. Saving the Model...
#
# Epoch: 335
# Train Loss: 0.552983 Acc: 0.7150
# Elapsed 72902.68s, 216.97 s/epoch, 0.36 s/batch, ets 13886.22s
#
# Test set: Average loss: 0.4722, Accuracy: 469/600 (78%)
#
# Epoch: 336
# Train Loss: 0.535908 Acc: 0.7188
# Elapsed 73118.36s, 216.97 s/epoch, 0.36 s/batch, ets 13669.01s
#
# Test set: Average loss: 0.4715, Accuracy: 466/600 (78%)
#
# Epoch: 337
# Train Loss: 0.534441 Acc: 0.7171
# Elapsed 73334.05s, 216.96 s/epoch, 0.36 s/batch, ets 13451.81s
#
# Test set: Average loss: 0.4737, Accuracy: 474/600 (79%)
#
# Epoch: 338
# Train Loss: 0.533747 Acc: 0.7179
# Elapsed 73549.90s, 216.96 s/epoch, 0.36 s/batch, ets 13234.64s
#
# Test set: Average loss: 0.4655, Accuracy: 466/600 (78%)
#
# Epoch: 339
# Train Loss: 0.536253 Acc: 0.7096
# Elapsed 73765.78s, 216.96 s/epoch, 0.36 s/batch, ets 13017.49s
#
# Test set: Average loss: 0.4911, Accuracy: 475/600 (79%)
#
# Epoch: 340
# Train Loss: 0.527849 Acc: 0.7317
# Elapsed 73981.62s, 216.95 s/epoch, 0.36 s/batch, ets 12800.34s
#
# Test set: Average loss: 0.5025, Accuracy: 466/600 (78%)
#
# Epoch: 341
# Train Loss: 0.536904 Acc: 0.7242
# Elapsed 74197.46s, 216.95 s/epoch, 0.36 s/batch, ets 12583.20s
#
# Test set: Average loss: 0.4590, Accuracy: 474/600 (79%)
#
# Epoch: 342
# Train Loss: 0.552440 Acc: 0.7113
# Elapsed 74413.29s, 216.95 s/epoch, 0.36 s/batch, ets 12366.06s
#
# Test set: Average loss: 0.4562, Accuracy: 470/600 (78%)
#
# Epoch: 343
# Train Loss: 0.511178 Acc: 0.7433
# Elapsed 74629.14s, 216.95 s/epoch, 0.36 s/batch, ets 12148.93s
#
# Test set: Average loss: 0.4495, Accuracy: 482/600 (80%)
#
# Epoch: 344
# Train Loss: 0.526593 Acc: 0.7271
# Elapsed 74844.84s, 216.94 s/epoch, 0.36 s/batch, ets 11931.79s
#
# Test set: Average loss: 0.4468, Accuracy: 476/600 (79%)
#
# Epoch: 345
# Train Loss: 0.514450 Acc: 0.7308
# Elapsed 75060.67s, 216.94 s/epoch, 0.36 s/batch, ets 11714.67s
#
# Test set: Average loss: 0.4671, Accuracy: 470/600 (78%)
#
# Epoch: 346
# Train Loss: 0.521487 Acc: 0.7300
# Elapsed 75276.52s, 216.94 s/epoch, 0.36 s/batch, ets 11497.57s
#
# Test set: Average loss: 0.4634, Accuracy: 471/600 (78%)
#
# Epoch: 347
# Train Loss: 0.538171 Acc: 0.7254
# Elapsed 75492.36s, 216.93 s/epoch, 0.36 s/batch, ets 11280.47s
#
# Test set: Average loss: 0.4477, Accuracy: 481/600 (80%)
#
# Epoch: 348
# Train Loss: 0.522528 Acc: 0.7196
# Elapsed 75708.21s, 216.93 s/epoch, 0.36 s/batch, ets 11063.38s
#
# Test set: Average loss: 0.4548, Accuracy: 474/600 (79%)
#
# Epoch: 349
# Train Loss: 0.520033 Acc: 0.7321
# Elapsed 75923.89s, 216.93 s/epoch, 0.36 s/batch, ets 10846.27s
#
# Test set: Average loss: 0.4593, Accuracy: 483/600 (80%)
#
# Epoch: 350
# Train Loss: 0.546849 Acc: 0.7067
# Elapsed 76139.73s, 216.92 s/epoch, 0.36 s/batch, ets 10629.19s
#
# Test set: Average loss: 0.4645, Accuracy: 470/600 (78%)
#
# Epoch: 351
# Train Loss: 0.515118 Acc: 0.7338
# Elapsed 76355.58s, 216.92 s/epoch, 0.36 s/batch, ets 10412.12s
#
# Test set: Average loss: 0.4276, Accuracy: 485/600 (81%)
#
# Model Improved. Saving the Model...
#
# Epoch: 352
# Train Loss: 0.514864 Acc: 0.7350
# Elapsed 76580.14s, 216.94 s/epoch, 0.36 s/batch, ets 10196.22s
#
# Test set: Average loss: 0.4270, Accuracy: 483/600 (80%)
#
# Model Improved. Saving the Model...
#
# Epoch: 353
# Train Loss: 0.520099 Acc: 0.7338
# Elapsed 76805.02s, 216.96 s/epoch, 0.36 s/batch, ets 9980.31s
#
# Test set: Average loss: 0.4443, Accuracy: 489/600 (82%)
#
# Epoch: 354
# Train Loss: 0.528323 Acc: 0.7271
# Elapsed 77020.90s, 216.96 s/epoch, 0.36 s/batch, ets 9763.21s
#
# Test set: Average loss: 0.4533, Accuracy: 483/600 (80%)
#
# Epoch: 355
# Train Loss: 0.521376 Acc: 0.7338
# Elapsed 77236.76s, 216.96 s/epoch, 0.36 s/batch, ets 9546.12s
#
# Test set: Average loss: 0.4777, Accuracy: 481/600 (80%)
#
# Epoch: 356
# Train Loss: 0.508976 Acc: 0.7454
# Elapsed 77452.60s, 216.95 s/epoch, 0.36 s/batch, ets 9329.02s
#
# Test set: Average loss: 0.4574, Accuracy: 469/600 (78%)
#
# Epoch: 357
# Train Loss: 0.533713 Acc: 0.7204
# Elapsed 77668.44s, 216.95 s/epoch, 0.36 s/batch, ets 9111.94s
#
# Test set: Average loss: 0.4925, Accuracy: 472/600 (79%)
#
# Epoch: 358
# Train Loss: 0.517480 Acc: 0.7371
# Elapsed 77884.28s, 216.95 s/epoch, 0.36 s/batch, ets 8894.86s
#
# Test set: Average loss: 0.4530, Accuracy: 487/600 (81%)
#
# Epoch: 359
# Train Loss: 0.533794 Acc: 0.7271
# Elapsed 78100.14s, 216.94 s/epoch, 0.36 s/batch, ets 8677.79s
#
# Test set: Average loss: 0.4489, Accuracy: 485/600 (81%)
#
# Epoch: 360
# Train Loss: 0.520621 Acc: 0.7246
# Elapsed 78315.97s, 216.94 s/epoch, 0.36 s/batch, ets 8460.73s
#
# Test set: Average loss: 0.4412, Accuracy: 489/600 (82%)
#
# Epoch: 361
# Train Loss: 0.532497 Acc: 0.7217
# Elapsed 78531.82s, 216.94 s/epoch, 0.36 s/batch, ets 8243.67s
#
# Test set: Average loss: 0.4497, Accuracy: 483/600 (80%)
#
# Epoch: 362
# Train Loss: 0.515608 Acc: 0.7408
# Elapsed 78747.67s, 216.94 s/epoch, 0.36 s/batch, ets 8026.62s
#
# Test set: Average loss: 0.4628, Accuracy: 462/600 (77%)
#
# Epoch: 363
# Train Loss: 0.509380 Acc: 0.7442
# Elapsed 78963.49s, 216.93 s/epoch, 0.36 s/batch, ets 7809.58s
#
# Test set: Average loss: 0.4334, Accuracy: 491/600 (82%)
#
# Epoch: 364
# Train Loss: 0.512617 Acc: 0.7404
# Elapsed 79179.33s, 216.93 s/epoch, 0.36 s/batch, ets 7592.54s
#
# Test set: Average loss: 0.4322, Accuracy: 493/600 (82%)
#
# Epoch: 365
# Train Loss: 0.513633 Acc: 0.7442
# Elapsed 79395.17s, 216.93 s/epoch, 0.36 s/batch, ets 7375.51s
#
# Test set: Average loss: 0.4477, Accuracy: 484/600 (81%)
#
# Epoch: 366
# Train Loss: 0.510993 Acc: 0.7379
# Elapsed 79611.01s, 216.92 s/epoch, 0.36 s/batch, ets 7158.48s
#
# Test set: Average loss: 0.4644, Accuracy: 481/600 (80%)
#
# Epoch: 367
# Train Loss: 0.519869 Acc: 0.7321
# Elapsed 79826.88s, 216.92 s/epoch, 0.36 s/batch, ets 6941.47s
#
# Test set: Average loss: 0.4823, Accuracy: 476/600 (79%)
#
# Epoch: 368
# Train Loss: 0.516217 Acc: 0.7325
# Elapsed 80042.73s, 216.92 s/epoch, 0.36 s/batch, ets 6724.46s
#
# Test set: Average loss: 0.4450, Accuracy: 481/600 (80%)
#
# Epoch: 369
# Train Loss: 0.503679 Acc: 0.7429
# Elapsed 80258.57s, 216.92 s/epoch, 0.36 s/batch, ets 6507.45s
#
# Test set: Average loss: 0.4459, Accuracy: 494/600 (82%)
#
# Epoch: 370
# Train Loss: 0.518292 Acc: 0.7379
# Elapsed 80474.41s, 216.91 s/epoch, 0.36 s/batch, ets 6290.45s
#
# Test set: Average loss: 0.4332, Accuracy: 495/600 (82%)
#
# Epoch: 371
# Train Loss: 0.525006 Acc: 0.7279
# Elapsed 80690.28s, 216.91 s/epoch, 0.36 s/batch, ets 6073.46s
#
# Test set: Average loss: 0.4565, Accuracy: 480/600 (80%)
#
# Epoch: 372
# Train Loss: 0.527849 Acc: 0.7421
# Elapsed 80906.12s, 216.91 s/epoch, 0.36 s/batch, ets 5856.48s
#
# Test set: Average loss: 0.4569, Accuracy: 483/600 (80%)
#
# Epoch: 373
# Train Loss: 0.506577 Acc: 0.7458
# Elapsed 81121.95s, 216.90 s/epoch, 0.36 s/batch, ets 5639.49s
#
# Test set: Average loss: 0.4352, Accuracy: 484/600 (81%)
#
# Epoch: 374
# Train Loss: 0.500464 Acc: 0.7500
# Elapsed 81337.78s, 216.90 s/epoch, 0.36 s/batch, ets 5422.52s
#
# Test set: Average loss: 0.4802, Accuracy: 475/600 (79%)
#
# Epoch: 375
# Train Loss: 0.505553 Acc: 0.7392
# Elapsed 81553.61s, 216.90 s/epoch, 0.36 s/batch, ets 5205.55s
#
# Test set: Average loss: 0.4792, Accuracy: 477/600 (80%)
#
# Epoch: 376
# Train Loss: 0.517941 Acc: 0.7358
# Elapsed 81769.45s, 216.90 s/epoch, 0.36 s/batch, ets 4988.59s
#
# Test set: Average loss: 0.4765, Accuracy: 477/600 (80%)
#
# Epoch: 377
# Train Loss: 0.517633 Acc: 0.7317
# Elapsed 81985.30s, 216.89 s/epoch, 0.36 s/batch, ets 4771.63s
#
# Test set: Average loss: 0.4509, Accuracy: 483/600 (80%)
#
# Epoch: 378
# Train Loss: 0.500869 Acc: 0.7404
# Elapsed 82201.14s, 216.89 s/epoch, 0.36 s/batch, ets 4554.68s
#
# Test set: Average loss: 0.4830, Accuracy: 464/600 (77%)
#
# Epoch: 379
# Train Loss: 0.511207 Acc: 0.7446
# Elapsed 82416.96s, 216.89 s/epoch, 0.36 s/batch, ets 4337.73s
#
# Test set: Average loss: 0.4391, Accuracy: 484/600 (81%)
#
# Epoch: 380
# Train Loss: 0.511968 Acc: 0.7425
# Elapsed 82632.82s, 216.88 s/epoch, 0.36 s/batch, ets 4120.80s
#
# Test set: Average loss: 0.4343, Accuracy: 488/600 (81%)
#
# Epoch: 381
# Train Loss: 0.506465 Acc: 0.7442
# Elapsed 82848.66s, 216.88 s/epoch, 0.36 s/batch, ets 3903.86s
#
# Test set: Average loss: 0.4463, Accuracy: 488/600 (81%)
#
# Epoch: 382
# Train Loss: 0.508401 Acc: 0.7475
# Elapsed 83064.50s, 216.88 s/epoch, 0.36 s/batch, ets 3686.94s
#
# Test set: Average loss: 0.4861, Accuracy: 476/600 (79%)
#
# Epoch: 383
# Train Loss: 0.511364 Acc: 0.7350
# Elapsed 83280.36s, 216.88 s/epoch, 0.36 s/batch, ets 3470.01s
#
# Test set: Average loss: 0.4556, Accuracy: 465/600 (78%)
#
# Epoch: 384
# Train Loss: 0.516015 Acc: 0.7325
# Elapsed 83496.19s, 216.87 s/epoch, 0.36 s/batch, ets 3253.10s
#
# Test set: Average loss: 0.4594, Accuracy: 484/600 (81%)
#
# Epoch: 385
# Train Loss: 0.519003 Acc: 0.7354
# Elapsed 83712.04s, 216.87 s/epoch, 0.36 s/batch, ets 3036.19s
#
# Test set: Average loss: 0.4398, Accuracy: 484/600 (81%)
#
# Epoch: 386
# Train Loss: 0.500991 Acc: 0.7450
# Elapsed 83927.88s, 216.87 s/epoch, 0.36 s/batch, ets 2819.28s
#
# Test set: Average loss: 0.4689, Accuracy: 478/600 (80%)
#
# Epoch: 387
# Train Loss: 0.495185 Acc: 0.7408
# Elapsed 84143.57s, 216.86 s/epoch, 0.36 s/batch, ets 2602.38s
#
# Test set: Average loss: 0.4440, Accuracy: 476/600 (79%)
#
# Epoch: 388
# Train Loss: 0.509047 Acc: 0.7392
# Elapsed 84359.44s, 216.86 s/epoch, 0.36 s/batch, ets 2385.49s
#
# Test set: Average loss: 0.4357, Accuracy: 485/600 (81%)
#
# Epoch: 389
# Train Loss: 0.511119 Acc: 0.7388
# Elapsed 84575.27s, 216.86 s/epoch, 0.36 s/batch, ets 2168.60s
#
# Test set: Average loss: 0.4753, Accuracy: 483/600 (80%)
#
# Epoch: 390
# Train Loss: 0.499781 Acc: 0.7429
# Elapsed 84791.10s, 216.86 s/epoch, 0.36 s/batch, ets 1951.71s
#
# Test set: Average loss: 0.4420, Accuracy: 497/600 (83%)
#
# Epoch: 391
# Train Loss: 0.495809 Acc: 0.7458
# Elapsed 85006.96s, 216.85 s/epoch, 0.36 s/batch, ets 1734.84s
#
# Test set: Average loss: 0.4180, Accuracy: 497/600 (83%)
#
# Model Improved. Saving the Model...
#
# Epoch: 392
# Train Loss: 0.516073 Acc: 0.7433
# Elapsed 85231.66s, 216.87 s/epoch, 0.36 s/batch, ets 1518.12s
#
# Test set: Average loss: 0.4094, Accuracy: 490/600 (82%)
#
# Model Improved. Saving the Model...
#
# Epoch: 393
# Train Loss: 0.511650 Acc: 0.7404
# Elapsed 85456.36s, 216.89 s/epoch, 0.36 s/batch, ets 1301.37s
#
# Test set: Average loss: 0.5168, Accuracy: 492/600 (82%)
#
# Epoch: 394
# Train Loss: 0.513985 Acc: 0.7404
# Elapsed 85672.06s, 216.89 s/epoch, 0.36 s/batch, ets 1084.46s
#
# Test set: Average loss: 0.4740, Accuracy: 485/600 (81%)
#
# Epoch: 395
# Train Loss: 0.513619 Acc: 0.7317
# Elapsed 85887.88s, 216.89 s/epoch, 0.36 s/batch, ets 867.55s
#
# Test set: Average loss: 0.4402, Accuracy: 492/600 (82%)
#
# Epoch: 396
# Train Loss: 0.504614 Acc: 0.7354
# Elapsed 86103.73s, 216.89 s/epoch, 0.36 s/batch, ets 650.66s
#
# Test set: Average loss: 0.4376, Accuracy: 500/600 (83%)
#
# Epoch: 397
# Train Loss: 0.509547 Acc: 0.7425
# Elapsed 86319.58s, 216.88 s/epoch, 0.36 s/batch, ets 433.77s
#
# Test set: Average loss: 0.4315, Accuracy: 487/600 (81%)
#
# Epoch: 398
# Train Loss: 0.503290 Acc: 0.7512
# Elapsed 86535.23s, 216.88 s/epoch, 0.36 s/batch, ets 216.88s
#
# Test set: Average loss: 0.4385, Accuracy: 481/600 (80%)
#
# Epoch: 399
# Train Loss: 0.502813 Acc: 0.7538
# Elapsed 86751.08s, 216.88 s/epoch, 0.36 s/batch, ets 0.00s
#
# Test set: Average loss: 0.4632, Accuracy: 493/600 (82%)
#
# Total time: 86761.57, Best Loss: 0.409

# %% [markdown]
# ## <font style="color:blue">4.10. Loss and Accuracy Plot</font>

# %%
plot_loss_accuracy(train_loss=[train_loss], 
                   val_loss=[val_loss], 
                   train_acc=[train_acc], 
                   val_acc=[val_acc], 
                   colors=['blue'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# # <font style="color:blue">5. Sample Prediction</font>
#
# Show some sample predictions.

# %% [markdown]
# ## <font style="color:blue">5.1. Make Predictions</font>

# %%
def prediction(model, device, batch_input):
    
    # send model to cpu/cuda according to your system configuration
    model.to(device)
    
    # it is important to do model.eval() before prediction
    model.eval()

    data = batch_input.to(device)

    output = model(data)

    # Score to probability using softmax
    prob = F.softmax(output, dim=1)

    # get the max probability
    pred_prob = prob.data.max(dim=1)[0]
    
    # get the index of the max probability
    pred_index = prob.data.max(dim=1)[1]
    
    return pred_index.cpu().numpy(), pred_prob.cpu().numpy()

# %% [markdown]
# ## <font style="color:blue">5.2. Get predictions on a batch</font>

# %%
def get_sample_prediction(model, data_root, mean, std):
    batch_size = 15

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
    
    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))
    
    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())
    
    data_len = test_dataset.__len__()
    
    interval = int(data_len/batch_size)
    
    imgs = []
    inputs = []
    targets = []
    for i in range(batch_size):
        index = i * interval
        trans_input, target = test_dataset_trans.__getitem__(index)
        img, _ = test_dataset.__getitem__(index)
        
        imgs.append(img)
        inputs.append(trans_input)
        targets.append(target)
        
    inputs = torch.stack(inputs)
        
    cls, prob = prediction(model, device, batch_input=inputs)
    
    plt.style.use('default')
    plt.rcParams["figure.figsize"] = (15, 9)
    fig = plt.figure()
    
    
    for i, target in enumerate(targets):
        plt.subplot(3, 5, i+1)
        img = transforms.functional.to_pil_image(imgs[i])
        plt.imshow(img)
        plt.gca().set_title('P:{0}({1:.2}), T:{2}'.format(test_dataset.classes[cls[i]], 
                                                     prob[i], 
                                                     test_dataset.classes[targets[i]]))
    fig.savefig('sample_prediction.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:blue">5.3. Load Model and Run Inference</font>

# %%
m = MyModel(0.25, batch_norm=True)

m = load_model(m)

train_config = TrainingConfiguration()

test_data_path = os.path.join(train_config.data_root, 'validation')

train_data_path = os.path.join(train_config.data_root, 'training')

mean, std = get_mean_std(train_data_path)


get_sample_prediction(m, test_data_path, mean, std)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2400, 0.2356, 0.2306])

# %% [markdown]
# You can see that even though the network is trained on a very small subset if data, the predictions are not that bad. This means that our model is ready to be trained.

# %% [markdown]
# # <font style="color:red">6. Display Confusion Matrix [10 Points]</font>
# Display the confusion matrix for the above problem. You can refer to the earlier lectures on Performance metrics for reference.
#
# The output should something similar to this:
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/02/c3_w5_sample_confusion_matrix.png' width=600>

# %%
from sklearn.metrics import confusion_matrix
def plot_cm(model, test_data_path, mean, std):
    batch_size = 15
    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
    
    test_loader = data_loader(test_data_path, 
                              transform=image_common_transforms(mean, std),
                              batch_size=batch_size,
                              shuffle=False,
                              num_workers=num_workers)
    preds = []
    targets = []
    for data, target in test_loader:
        cls, prob = prediction(model, device, batch_input=data)
        preds.append(cls)
        targets.append(target)
    
    # flatten the lists
    preds = [item for sublist in preds for item in sublist]
    targets = [item for sublist in targets for item in sublist]
    
    cm = confusion_matrix(targets, preds)
    #print(cm)
    cmap = plt.get_cmap('viridis')
    plt.style.use('default')
    plt.rcParams['figure.figsize'] = (15, 9)
    plt.imshow(cm, cmap=cmap)
    plt.title('Confusion Matrix')
    plt.colorbar()
    
    target_names = test_loader.dataset.classes
    tick_marks = np.arange(len(target_names))
    plt.xticks(tick_marks, target_names)
    plt.yticks(tick_marks, target_names)
    
    for i in range(3):
        for j in range(3):
            plt.text(j, i, cm[i,j], horizontalalignment='center', color='white')
    
    plt.ylabel('True')
    plt.xlabel('Predicted')
    return

# %%
m = MyModel(0.25, batch_norm=True)
m = load_model(m)
m.eval()
train_config = TrainingConfiguration()
train_data_path = os.path.join(train_config.data_root, 'training')
mean, std = get_mean_std(train_data_path)
test_data_path = os.path.join(train_config.data_root, 'validation')
plot_cm(m, test_data_path, mean, std)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2400, 0.2356, 0.2306])

# %% [markdown]
# After you have completed the assignment, <font style="color:red">upload and submit the 2 notebooks and the models folder</font> on the portal so that we can check and provide feedback.
