# %% [markdown]
# # <font style="color:blue">Project 1 - Part 1: Data Understanding & Pipeline Check</font>
# We will slightly modify the steps we discussed for training Neural Networks:
#
# - Step 1 - Understand your problem
# - Step 2A - Get the data
# - Step 2B - Explore & Understand your data
# - Step 2C - Create a sample data from the dataset
# - Step 3 - Data Preparation
# - Step 4 - Train a simple model on sample data and check the pipeline before proceeding to train the full network
# - Step 5 - Train on Full Data
# - Step 6 - Improve your model
#
# In this notebook we will go over the steps 1 to 4 in detail and do some coding along the way! You will implement Steps 5 & 6 in the next notebook.
#
# There are 30 points for this notebook. <font style="color:red">The sections which carry marks are written in Red for easy reference.</font>

# %% [markdown]
# # <font style="color:blue">Step 1: Understand your problem </font>
# As you already know, Image Classification refers to the process of classifying an image on the basis of its visual content. So, the goal for the model is to look at the image and predict which object is present in the image. Obviously, the number of objects which it can predict depends on how many objects you train it on.
#
# In our problem, we want to classify an input image between 3 animals - Cat, Dog and Panda.
#
# ### <font style="color:green">What do we need and how to achieve that? </font>
# You need images of each animal with the correct label and train a decent size network which understands the input image.

# %% [markdown]
# # <font style="color:blue">Step 2A: Get the data </font>
# We will be using a dataset from kaggle. [**Check it out here**](https://www.kaggle.com/ashishsaxena2209/animal-image-datasetdog-cat-and-panda).
#
# It consists of 1000 images of each animal with all images of a particular animal in a separate folder. We have split it into 80:20 ratio for train:validation which you can download from [**here**](https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1).

# %%
# !wget "https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1" -O data.zip

# %% [markdown]
# ### <font style="color:green">Extract the data</font>

# %%
# !unzip -q data.zip

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # <font style="color:blue">Step 2B: Explore the data </font>[5 Points]
# Let us explore the data and see some examples

# %% [markdown]
# ### <font style="color:green">Folder Structure </font>

# %%
# !tree -d ./cat-dog-panda
# Out:
# ./cat-dog-panda
# ├── training
# │   ├── cat
# │   ├── dog
# │   └── panda
# └── validation
#     ├── cat
#     ├── dog
#     └── panda
#
# 8 directories

# %% [markdown]
# ### <font style="color:green">Import the datasets module</font>
# We will use the datasets module to load the data and check out the structure of data.

# %%
from torchvision import datasets

# %% [markdown]
# ### <font style="color:green">Create a dataset object </font>

# %%
train_data = datasets.ImageFolder("./cat-dog-panda/training")
validation_data = datasets.ImageFolder("./cat-dog-panda/validation")

# %% [markdown]
# ### <font style="color:green">List the classes</font>
# It simply prints the folders present inside the training or validation folders.

# %%
print(train_data.classes)
print(validation_data.classes)
# Out:
# ['cat', 'dog', 'panda']
# ['cat', 'dog', 'panda']

# %% [markdown]
# ### <font style="color:green">Get the class ID to Name Mapping</font>

# %%
print(train_data.class_to_idx)
print(validation_data.class_to_idx)
# Out:
# {'cat': 0, 'dog': 1, 'panda': 2}
# {'cat': 0, 'dog': 1, 'panda': 2}

# %% [markdown]
# ### <font style="color:red">Find the number of samples in training and validation folders [2 Points]</font>

# %%
print(len(train_data))
print(len(validation_data))
# Out:
# 2400
# 600

# %% [markdown]
# ### <font style="color:red">Display some samples [3 Points]</font>
# Display one sample from each class. We know that the train dataset contains
#
# - cats from 0 to 799
# - dogs from 800 to 1599
# - pandas from 1600 to 2399
#
# Take one sample from each class and display using matplotlib

# %%
img, target = train_data[0]

print('image size: {}, target: {}'.format(img.size, target))

plt.imshow(img)
plt.show()
# Out:
# image size: (500, 374), target: 0

# %%
img, target = train_data[800]

print('image size: {}, target: {}'.format(img.size, target))

plt.imshow(img)
plt.show()
# Out:
# image size: (382, 478), target: 1

# %%
img, target = train_data[1600]

print('image size: {}, target: {}'.format(img.size, target))

plt.imshow(img)
plt.show()
# Out:
# image size: (480, 500), target: 2

# %% [markdown]
# One thing to note from the above is that the images are of different size.

# %% [markdown]
# # <font style="color:blue">Step 2C: Create sample data</font>
# We will take 5% images from training and validation and create a small dataset which we will use as a sample to check our training pipeline.

# %%
import torch
import numpy as np

# %%
subset_size = .05

# %% [markdown]
# ### <font style="color:green">Create a subset from the original data</font>
# Instead of creating a copy from the original data, we can use the `Subset` method in Torch to create a subset of the data which will be used for training the model.
#
# Let us see how it can be done since it was not covered earlier in any of the lectures.

# %%
train_subset = torch.utils.data.Subset(train_data,np.arange(0,len(train_data),1./subset_size))
validation_subset = torch.utils.data.Subset(validation_data,np.arange(0,len(validation_data),1./subset_size))

# %%
train_subset_loader = torch.utils.data.DataLoader(train_subset,
                                         batch_size=8,
                                         num_workers=1,
                                         shuffle=False)
validation_subset_loader = torch.utils.data.DataLoader(validation_subset, 
                                         batch_size=8,
                                         num_workers=1,
                                         shuffle=False)

# %%
print("Train Subset Size: {}".format(len(train_subset_loader.dataset)))
print("Validation Subset Size: {}".format(len(validation_subset_loader.dataset)))
# Out:
# Train Subset Size: 120
# Validation Subset Size: 30

# %% [markdown]
# You can see that the subset data is only 5% of the original training and validation data.

# %% [markdown]
# We will create a separate function called `subset_data_loader` to create data loaders for subsets.

# %% [markdown]
# # <font style="color:blue">Step 3. Data Preparation</font> [5 Points]
# Now that we have seen how our data is organized, we can configure the train and test loaders to feed to our training pipeline.

# %% [markdown]
# ## <font style="color:blue">3.1. Import Libraries </font>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import os
import time

from typing import Iterable
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import datasets, transforms

from torch.optim import lr_scheduler

# %% [markdown]
# ## <font style="color:blue">3.2. Image Transforms</font>
# As you know, we need to normalize the data in some standard ways such as subtracting mean, making all images of same size, rescaling the range to [0,1] etc. All these operations are done using the following functions.

# %% [markdown]
# ### <font style="color:green">3.2.1. Compulsary preprocessing transforms</font>

# %%
def image_preprocess_transforms():
    
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor()
        ])
    
    return preprocess

# %% [markdown]
# ### <font style="color:green">3.2.2. Common Image Transforms</font>
# Normalize for mean and std.
#
# You can add any other transforms here as per your dataset.

# %%
def image_common_transforms(mean=(0.4611, 0.4359, 0.3905), std=(0.2193, 0.2150, 0.2109)):
    preprocess = image_preprocess_transforms()
    
    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std)
    ])
    
    return common_transforms

# %% [markdown]
# ### <font style="color:green">3.2.3. Mean and STD</font>
# Function for getting mean and variance

# %%
def get_mean_std(data_root, num_workers=4):
    
    transform = image_preprocess_transforms()
    
    loader = data_loader(data_root, transform)

    mean = 0.
    std = 0.
    
    for images, _ in loader:
        batch_samples = images.size(0) # batch size (the last batch can have smaller size!)
        images = images.view(batch_samples, images.size(1), -1)
        mean += images.mean(2).sum(0)
        std += images.std(2).sum(0)

    mean /= len(loader.dataset)
    std /= len(loader.dataset)
    
    print('mean: {}, std: {}'.format(mean, std))
    
    return mean, std

# %% [markdown]
# ## <font style="color:blue">3.3. Data Loaders </font>

# %% [markdown]
# ### <font style="color:green">3.3.1. Data Loader for Full Data</font>
# Data loader for generating batches of data to be used by the training routine

# %%
def data_loader(data_root, transform, batch_size=16, shuffle=False, num_workers=2):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)
    
    loader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %% [markdown]
# ### <font style="color:green">3.3.2. Data Loader for Subset</font>
# Data loader which uses the `subset` to generate batches

# %%
def subset_data_loader(data_root, transform, batch_size=8, shuffle=False, num_workers=2, subset_size=0.05):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)
    
    data_subset = torch.utils.data.Subset(dataset,np.arange(0,len(dataset),1./subset_size).astype(int))

    loader = torch.utils.data.DataLoader(data_subset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %% [markdown]
# ## <font style="color:red">3.4. Prepare Data [5 Points]</font>
# The main function which uses all the above functions to generate the train and test dataloaders.

# %%
def get_data(batch_size, data_root, num_workers=4, data_augmentation=False):
    
    train_data_path = os.path.join(data_root, 'training')
       
    mean, std = get_mean_std(data_root=train_data_path, num_workers=num_workers)
    
    common_transforms = image_common_transforms(mean, std)
        
   
    # if data_augmentation is true 
    # data augmentation implementation
    if data_augmentation:    
        train_transforms = transforms.Compose([ # 1. need to define random augmentation
            transforms.RandomChoice([
                transforms.RandomHorizontalFlip(),
                transforms.RandomVerticalFlip(),
                transforms.RandomRotation(20, fill=(0,))
            ]),
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])
    # else do common transforms
    else:
        train_transforms = common_transforms
        
        
    # train dataloader
    train_loader = subset_data_loader(train_data_path, 
                               train_transforms, 
                               batch_size=batch_size, 
                               shuffle=True, 
                               num_workers=num_workers)
    
    # test dataloader
    test_data_path = os.path.join(data_root, 'validation')
    
    test_loader = subset_data_loader(test_data_path, 
                              common_transforms, # 2. must be common transforms only
                              batch_size=batch_size, 
                              shuffle=False, 
                              num_workers=num_workers)
    print("Train Subset Size: {}".format(len(train_loader.dataset)))
    print("Validation Subset Size: {}".format(len(test_loader.dataset)))
    return train_loader, test_loader

# %% [markdown]
# ### <font style="color:red">Question </font>[5 Points]
# There are two mistakes in the above code snippet. Mention these mistakes and correct it. ( Note that the rest of the code will run even if you cannot spot the mistake.)

# %% [markdown]
# # <font style="color:blue">Step 4: Train a simple Model</font>
# It is time to create the training pipeline and train a simple model on the sample data. We are providing most of the code in this section as you have to make the changes in the next notebook.

# %% [markdown]
# ## <font style="color:red">4.1. Configurations [ 5 Points]</font>
#
# Define configurations in the section — a configuration like training configuration, system configuration. In the section, you can define batch size, data path, learning rate, etc.
#
# ### <font style="color:red">Question </font>[5 Points]:
# You need to set up the training pipeline with a batchsize of 4 and run the experiment for 100 epochs. Make these changes in the Configrations given below.

# %% [markdown]
# ### <font style="color:green">4.1.1. System Configuration</font>

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 21  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# ### <font style="color:green">4.1.2. Training Configuration</font>

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 4 
    epochs_count: int = 100  
    init_learning_rate: float = 0.0001  # initial learning rate for lr scheduler
    log_interval: int = 5  
    test_interval: int = 1  
    data_root: str = "./cat-dog-panda" 
    num_workers: int = 2  
    device: str = 'cuda'

# %% [markdown]
# ### <font style="color:green">4.1.3. System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# ## <font style="color:blue">4.2. Training Function</font>
# We are already familiar with the training function. You won't need to make any changes to this.

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int
) -> None:
    
    # change model in training mood
    model.train()
    
    # to get batch loss
    batch_loss = np.array([])
    
    # to get batch accuracy
    batch_acc = np.array([])
        
    for batch_idx, (data, target) in enumerate(train_loader):
        
        # clone target
        indx_target = target.clone()
        # send data to device (its is medatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()
        
        # forward pass to the model
        output = model(data)
        
        # cross entropy loss
        loss = F.cross_entropy(output, target)
        
        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gardients
        optimizer.step()
        
        batch_loss = np.append(batch_loss, [loss.item()])
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
            
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]  
                        
        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()
            
        # accuracy
        acc = float(correct) / float(len(data))
        
        batch_acc = np.append(batch_acc, [acc])
            
    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    print('Epoch: {} \nTrain Loss: {:.6f} Acc: {:.4f}'.format(epoch_idx, epoch_loss, epoch_acc))
    return epoch_loss, epoch_acc

# %% [markdown]
# ## <font style="color:blue">4.3. Validation Function</font>

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader,
) -> float:
    # 
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)
        
        target = target.to(train_config.device)
        
        output = model(data)
        # add loss for each mini batch
        test_loss += F.cross_entropy(output, target).item()
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
        
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1] 
        
        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)  
    
    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
    
    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )
    
    return test_loss, accuracy/100.0

# %% [markdown]
# ## <font style="color:blue">4.4. Save the Model</font>

# %%
def save_model(model, device, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    model_path = os.path.join(model_dir, model_file_name)

    # make sure you transfer the model to cpu.
    if device == 'cuda':
        model.to('cpu')

    # save the state_dict
    torch.save(model.state_dict(), model_path)
    
    if device == 'cuda':
        model.to('cuda')
    
    return

# %% [markdown]
# ## <font style="color:blue">4.5. Load the Model</font>

# %%
def load_model(model, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    model_path = os.path.join(model_dir, model_file_name)

    # loading the model and getting model parameters by using load_state_dict
    model.load_state_dict(torch.load(model_path))
    
    return model

# %% [markdown]
# ## <font style="color:blue">4.6. Main Function for Training</font>
#
# One thing to note here is that before calling the train function, we are calculating the validation loss and we know that it should be close to `log(num_classes)` and the accuracy should be close to `1/num_classes`.

# %%
def main(model, optimizer, scheduler=None, system_configuration=SystemConfiguration(), 
         training_configuration=TrainingConfiguration(), data_augmentation=True):
    
    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count

    # if GPU is available use training config, 
    # else lowers batch_size, num_workers and epochs count
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
        batch_size_to_set = 16
        num_workers_to_set = 4

    # data loader
    train_loader, test_loader = get_data(
        batch_size=batch_size_to_set,
        data_root=training_configuration.data_root,
        num_workers=num_workers_to_set,
        data_augmentation=data_augmentation
    )
    
    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set
    )
        
    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    best_loss = torch.tensor(np.inf)
    
    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])
    
    # epch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])
    
    # Calculate Initial Test Loss
    init_val_loss, init_val_accuracy = validate(training_configuration, model, test_loader)
    print("Initial Test Loss : {:.6f}, \nInitial Test Accuracy : {:.3f}%\n".format(init_val_loss, 
                                                                                   init_val_accuracy*100))
    
    # trainig time measurement
    t_begin = time.time()
    for epoch in range(training_configuration.epochs_count):
        
        # Train
        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch)
        
        epoch_train_loss = np.append(epoch_train_loss, [train_loss])
        
        epoch_train_acc = np.append(epoch_train_acc, [train_acc])

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time
        
        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )

        # Validate
        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)
            
            epoch_test_loss = np.append(epoch_test_loss, [current_loss])
        
            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])
            
            if current_loss < best_loss:
                best_loss = current_loss
                print('Model Improved. Saving the Model...\n')
                save_model(model, device=training_configuration.device)
        
                
    print("Total time: {:.2f}, Best Loss: {:.3f}".format(time.time() - t_begin, best_loss))
    
    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %% [markdown]
# ## <font style="color:blue">4.7. Plot Loss and Accuracy</font>

# %%
def plot_loss_accuracy(train_loss, val_loss, train_acc, val_acc, colors, 
                       loss_legend_loc='upper center', acc_legend_loc='upper left', 
                       fig_size=(20, 10), sub_plot1=(1, 2, 1), sub_plot2=(1, 2, 2)):
    
    plt.rcParams["figure.figsize"] = fig_size
    fig = plt.figure()
    
    plt.subplot(sub_plot1[0], sub_plot1[1], sub_plot1[2])
    
    for i in range(len(train_loss)):
        x_train = range(len(train_loss[i]))
        x_val = range(len(val_loss[i]))
        
        min_train_loss = train_loss[i].min()
        
        min_val_loss = val_loss[i].min()
        
        plt.plot(x_train, train_loss[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN LOSS ({0:.4})".format(min_train_loss))
        plt.plot(x_val, val_loss[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID LOSS ({0:.4})".format(min_val_loss))
        
    plt.xlabel('epoch no.')
    plt.ylabel('loss')
    plt.legend(loc=loss_legend_loc)
    plt.title('Training and Validation Loss')
        
    plt.subplot(sub_plot2[0], sub_plot2[1], sub_plot2[2])
    
    for i in range(len(train_acc)):
        x_train = range(len(train_acc[i]))
        x_val = range(len(val_acc[i]))
        
        max_train_acc = train_acc[i].max() 
        
        max_val_acc = val_acc[i].max() 
        
        plt.plot(x_train, train_acc[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN ACC ({0:.4})".format(max_train_acc))
        plt.plot(x_val, val_acc[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID ACC ({0:.4})".format(max_val_acc))
        
    plt.xlabel('epoch no.')
    plt.ylabel('accuracy')
    plt.legend(loc=acc_legend_loc)
    plt.title('Training and Validation Accuracy')
    
    fig.savefig('sample_loss_acc_plot.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:blue">4.8. Define Model</font>
#
# In the section,  define the CNN model and train the model.

# %%
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()

        # convolution layers
        self._body = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=7),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
        )

        
        # Fully connected layers
        self._head = nn.Sequential(
            nn.Linear(in_features=64*52*52, out_features=1024), 
            nn.ReLU(inplace=True),
            
            nn.Linear(in_features=1024, out_features=3)
            
        )
    
    def forward(self, x):
        
        # apply feature extractor
        x = self._body(x)
        # flatten the output of conv layers
        # dimension should be batch_size * number_of weight_in_last conv_layer
        x = x.view(x.size()[0], -1)
        # apply classification head
        x = self._head(x)
        
        
        return x

# %% [markdown]
# ## <font style="color:blue">4.9. Training</font>

# %%
model = MyModel()
print(model)

# get optimizer
train_config = TrainingConfiguration()

# optimizer
optimizer = optim.Adam(
    model.parameters(),
    lr = train_config.init_learning_rate
)
# Out:
# MyModel(
#   (_body): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (_head): Sequential(
#     (0): Linear(in_features=173056, out_features=1024, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=1024, out_features=3, bias=True)
#   )
# )

# %%
# train and validate
model, train_loss, train_acc, val_loss, val_acc = main(model, optimizer, scheduler=None, data_augmentation=False)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2400, 0.2356, 0.2306])
#
# Test set: Average loss: 1.0878, Accuracy: 10/30 (33%)
#
# Initial Test Loss : 1.087774,
# Initial Test Accuracy : 33.333%
#
# Epoch: 0
# Train Loss: 1.367960 Acc: 0.4000
# Elapsed 3.06s, 3.06 s/epoch, 0.10 s/batch, ets 302.94s
#
# Test set: Average loss: 0.8505, Accuracy: 20/30 (67%)
#
# Model Improved. Saving the Model...
#
# Epoch: 1
# Train Loss: 0.619959 Acc: 0.7500
# Elapsed 7.04s, 3.52 s/epoch, 0.12 s/batch, ets 344.95s
#
# Test set: Average loss: 0.6999, Accuracy: 19/30 (63%)
#
# Model Improved. Saving the Model...
#
# Epoch: 2
# Train Loss: 0.359183 Acc: 0.8583
# Elapsed 11.44s, 3.81 s/epoch, 0.13 s/batch, ets 369.77s
#
# Test set: Average loss: 0.6068, Accuracy: 21/30 (70%)
#
# Model Improved. Saving the Model...
#
# Epoch: 3
# Train Loss: 0.139940 Acc: 0.9833
# Elapsed 15.89s, 3.97 s/epoch, 0.13 s/batch, ets 381.39s
#
# Test set: Average loss: 0.6552, Accuracy: 18/30 (60%)
#
# Epoch: 4
# Train Loss: 0.035494 Acc: 1.0000
# Elapsed 18.75s, 3.75 s/epoch, 0.12 s/batch, ets 356.16s
#
# Test set: Average loss: 0.7154, Accuracy: 16/30 (53%)
#
# Epoch: 5
# Train Loss: 0.014575 Acc: 1.0000
# Elapsed 21.58s, 3.60 s/epoch, 0.12 s/batch, ets 338.09s
#
# Test set: Average loss: 0.8864, Accuracy: 20/30 (67%)
#
# Epoch: 6
# Train Loss: 0.009056 Acc: 1.0000
# Elapsed 24.44s, 3.49 s/epoch, 0.12 s/batch, ets 324.68s
#
# Test set: Average loss: 0.8187, Accuracy: 18/30 (60%)
#
# Epoch: 7
# Train Loss: 0.004240 Acc: 1.0000
# Elapsed 27.29s, 3.41 s/epoch, 0.11 s/batch, ets 313.81s
#
# Test set: Average loss: 0.8503, Accuracy: 19/30 (63%)
#
# Epoch: 8
# Train Loss: 0.002358 Acc: 1.0000
# Elapsed 30.13s, 3.35 s/epoch, 0.11 s/batch, ets 304.67s
#
# Test set: Average loss: 0.8262, Accuracy: 17/30 (57%)
#
# Epoch: 9
# Train Loss: 0.001883 Acc: 1.0000
# Elapsed 32.95s, 3.29 s/epoch, 0.11 s/batch, ets 296.51s
#
# Test set: Average loss: 0.8697, Accuracy: 19/30 (63%)
#
# Epoch: 10
# Train Loss: 0.001284 Acc: 1.0000
# Elapsed 35.76s, 3.25 s/epoch, 0.11 s/batch, ets 289.36s
#
# Test set: Average loss: 0.8636, Accuracy: 19/30 (63%)
#
# Epoch: 11
# Train Loss: 0.000992 Acc: 1.0000
# Elapsed 38.61s, 3.22 s/epoch, 0.11 s/batch, ets 283.16s
#
# Test set: Average loss: 0.8919, Accuracy: 18/30 (60%)
#
# Epoch: 12
# Train Loss: 0.000803 Acc: 1.0000
# Elapsed 41.42s, 3.19 s/epoch, 0.11 s/batch, ets 277.21s
#
# Test set: Average loss: 0.9203, Accuracy: 18/30 (60%)
#
# Epoch: 13
# Train Loss: 0.000637 Acc: 1.0000
# Elapsed 44.25s, 3.16 s/epoch, 0.11 s/batch, ets 271.83s
#
# Test set: Average loss: 0.9344, Accuracy: 18/30 (60%)
#
# Epoch: 14
# Train Loss: 0.000512 Acc: 1.0000
# Elapsed 47.07s, 3.14 s/epoch, 0.10 s/batch, ets 266.76s
#
# Test set: Average loss: 0.9440, Accuracy: 18/30 (60%)
#
# Epoch: 15
# Train Loss: 0.000430 Acc: 1.0000
# Elapsed 49.90s, 3.12 s/epoch, 0.10 s/batch, ets 262.00s
#
# Test set: Average loss: 0.9676, Accuracy: 19/30 (63%)
#
# Epoch: 16
# Train Loss: 0.000376 Acc: 1.0000
# Elapsed 52.73s, 3.10 s/epoch, 0.10 s/batch, ets 257.43s
#
# Test set: Average loss: 0.9859, Accuracy: 18/30 (60%)
#
# Epoch: 17
# Train Loss: 0.000309 Acc: 1.0000
# Elapsed 55.55s, 3.09 s/epoch, 0.10 s/batch, ets 253.06s
#
# Test set: Average loss: 0.9984, Accuracy: 18/30 (60%)
#
# Epoch: 18
# Train Loss: 0.000263 Acc: 1.0000
# Elapsed 58.37s, 3.07 s/epoch, 0.10 s/batch, ets 248.84s
#
# Test set: Average loss: 1.0241, Accuracy: 18/30 (60%)
#
# Epoch: 19
# Train Loss: 0.000234 Acc: 1.0000
# Elapsed 61.35s, 3.07 s/epoch, 0.10 s/batch, ets 245.41s
#
# Test set: Average loss: 1.0257, Accuracy: 18/30 (60%)
#
# Epoch: 20
# Train Loss: 0.000207 Acc: 1.0000
# Elapsed 64.27s, 3.06 s/epoch, 0.10 s/batch, ets 241.78s
#
# Test set: Average loss: 1.0399, Accuracy: 18/30 (60%)
#
# Epoch: 21
# Train Loss: 0.000181 Acc: 1.0000
# Elapsed 67.09s, 3.05 s/epoch, 0.10 s/batch, ets 237.88s
#
# Test set: Average loss: 1.0533, Accuracy: 18/30 (60%)
#
# Epoch: 22
# Train Loss: 0.000161 Acc: 1.0000
# Elapsed 69.91s, 3.04 s/epoch, 0.10 s/batch, ets 234.03s
#
# Test set: Average loss: 1.0667, Accuracy: 18/30 (60%)
#
# Epoch: 23
# Train Loss: 0.000144 Acc: 1.0000
# Elapsed 72.83s, 3.03 s/epoch, 0.10 s/batch, ets 230.62s
#
# Test set: Average loss: 1.0770, Accuracy: 18/30 (60%)
#
# Epoch: 24
# Train Loss: 0.000130 Acc: 1.0000
# Elapsed 75.68s, 3.03 s/epoch, 0.10 s/batch, ets 227.03s
#
# Test set: Average loss: 1.0910, Accuracy: 17/30 (57%)
#
# Epoch: 25
# Train Loss: 0.000118 Acc: 1.0000
# Elapsed 78.48s, 3.02 s/epoch, 0.10 s/batch, ets 223.38s
#
# Test set: Average loss: 1.1055, Accuracy: 18/30 (60%)
#
# Epoch: 26
# Train Loss: 0.000104 Acc: 1.0000
# Elapsed 81.30s, 3.01 s/epoch, 0.10 s/batch, ets 219.81s
#
# Test set: Average loss: 1.1103, Accuracy: 19/30 (63%)
#
# Epoch: 27
# Train Loss: 0.000097 Acc: 1.0000
# Elapsed 84.15s, 3.01 s/epoch, 0.10 s/batch, ets 216.38s
#
# Test set: Average loss: 1.1276, Accuracy: 18/30 (60%)
#
# Epoch: 28
# Train Loss: 0.000088 Acc: 1.0000
# Elapsed 87.04s, 3.00 s/epoch, 0.10 s/batch, ets 213.09s
#
# Test set: Average loss: 1.1296, Accuracy: 19/30 (63%)
#
# Epoch: 29
# Train Loss: 0.000081 Acc: 1.0000
# Elapsed 89.89s, 3.00 s/epoch, 0.10 s/batch, ets 209.74s
#
# Test set: Average loss: 1.1436, Accuracy: 18/30 (60%)
#
# Epoch: 30
# Train Loss: 0.000074 Acc: 1.0000
# Elapsed 92.76s, 2.99 s/epoch, 0.10 s/batch, ets 206.47s
#
# Test set: Average loss: 1.1596, Accuracy: 17/30 (57%)
#
# Epoch: 31
# Train Loss: 0.000068 Acc: 1.0000
# Elapsed 95.58s, 2.99 s/epoch, 0.10 s/batch, ets 203.10s
#
# Test set: Average loss: 1.1593, Accuracy: 18/30 (60%)
#
# Epoch: 32
# Train Loss: 0.000063 Acc: 1.0000
# Elapsed 98.39s, 2.98 s/epoch, 0.10 s/batch, ets 199.76s
#
# Test set: Average loss: 1.1760, Accuracy: 18/30 (60%)
#
# Epoch: 33
# Train Loss: 0.000058 Acc: 1.0000
# Elapsed 101.22s, 2.98 s/epoch, 0.10 s/batch, ets 196.48s
#
# Test set: Average loss: 1.1799, Accuracy: 18/30 (60%)
#
# Epoch: 34
# Train Loss: 0.000053 Acc: 1.0000
# Elapsed 104.08s, 2.97 s/epoch, 0.10 s/batch, ets 193.30s
#
# Test set: Average loss: 1.1810, Accuracy: 18/30 (60%)
#
# Epoch: 35
# Train Loss: 0.000049 Acc: 1.0000
# Elapsed 106.97s, 2.97 s/epoch, 0.10 s/batch, ets 190.16s
#
# Test set: Average loss: 1.1942, Accuracy: 18/30 (60%)
#
# Epoch: 36
# Train Loss: 0.000046 Acc: 1.0000
# Elapsed 109.92s, 2.97 s/epoch, 0.10 s/batch, ets 187.15s
#
# Test set: Average loss: 1.2004, Accuracy: 18/30 (60%)
#
# Epoch: 37
# Train Loss: 0.000043 Acc: 1.0000
# Elapsed 112.82s, 2.97 s/epoch, 0.10 s/batch, ets 184.08s
#
# Test set: Average loss: 1.2140, Accuracy: 18/30 (60%)
#
# Epoch: 38
# Train Loss: 0.000040 Acc: 1.0000
# Elapsed 115.81s, 2.97 s/epoch, 0.10 s/batch, ets 181.13s
#
# Test set: Average loss: 1.2181, Accuracy: 18/30 (60%)
#
# Epoch: 39
# Train Loss: 0.000038 Acc: 1.0000
# Elapsed 118.73s, 2.97 s/epoch, 0.10 s/batch, ets 178.09s
#
# Test set: Average loss: 1.2272, Accuracy: 18/30 (60%)
#
# Epoch: 40
# Train Loss: 0.000035 Acc: 1.0000
# Elapsed 121.55s, 2.96 s/epoch, 0.10 s/batch, ets 174.91s
#
# Test set: Average loss: 1.2335, Accuracy: 18/30 (60%)
#
# Epoch: 41
# Train Loss: 0.000034 Acc: 1.0000
# Elapsed 124.41s, 2.96 s/epoch, 0.10 s/batch, ets 171.80s
#
# Test set: Average loss: 1.2427, Accuracy: 18/30 (60%)
#
# Epoch: 42
# Train Loss: 0.000032 Acc: 1.0000
# Elapsed 127.22s, 2.96 s/epoch, 0.10 s/batch, ets 168.64s
#
# Test set: Average loss: 1.2533, Accuracy: 18/30 (60%)
#
# Epoch: 43
# Train Loss: 0.000030 Acc: 1.0000
# Elapsed 130.03s, 2.96 s/epoch, 0.10 s/batch, ets 165.50s
#
# Test set: Average loss: 1.2555, Accuracy: 18/30 (60%)
#
# Epoch: 44
# Train Loss: 0.000028 Acc: 1.0000
# Elapsed 132.85s, 2.95 s/epoch, 0.10 s/batch, ets 162.37s
#
# Test set: Average loss: 1.2667, Accuracy: 18/30 (60%)
#
# Epoch: 45
# Train Loss: 0.000027 Acc: 1.0000
# Elapsed 135.67s, 2.95 s/epoch, 0.10 s/batch, ets 159.26s
#
# Test set: Average loss: 1.2704, Accuracy: 18/30 (60%)
#
# Epoch: 46
# Train Loss: 0.000025 Acc: 1.0000
# Elapsed 138.51s, 2.95 s/epoch, 0.10 s/batch, ets 156.19s
#
# Test set: Average loss: 1.2799, Accuracy: 18/30 (60%)
#
# Epoch: 47
# Train Loss: 0.000024 Acc: 1.0000
# Elapsed 141.34s, 2.94 s/epoch, 0.10 s/batch, ets 153.12s
#
# Test set: Average loss: 1.2840, Accuracy: 18/30 (60%)
#
# Epoch: 48
# Train Loss: 0.000023 Acc: 1.0000
# Elapsed 144.15s, 2.94 s/epoch, 0.10 s/batch, ets 150.04s
#
# Test set: Average loss: 1.2902, Accuracy: 18/30 (60%)
#
# Epoch: 49
# Train Loss: 0.000022 Acc: 1.0000
# Elapsed 146.97s, 2.94 s/epoch, 0.10 s/batch, ets 146.97s
#
# Test set: Average loss: 1.3010, Accuracy: 18/30 (60%)
#
# Epoch: 50
# Train Loss: 0.000021 Acc: 1.0000
# Elapsed 149.82s, 2.94 s/epoch, 0.10 s/batch, ets 143.95s
# Test set: Average loss: 1.2979, Accuracy: 18/30 (60%)
#
# Epoch: 51
# Train Loss: 0.000019 Acc: 1.0000
# Elapsed 152.64s, 2.94 s/epoch, 0.10 s/batch, ets 140.90s
#
# Test set: Average loss: 1.3087, Accuracy: 18/30 (60%)
#
# Epoch: 52
# Train Loss: 0.000019 Acc: 1.0000
# Elapsed 155.46s, 2.93 s/epoch, 0.10 s/batch, ets 137.86s
#
# Test set: Average loss: 1.3150, Accuracy: 18/30 (60%)
#
# Epoch: 53
# Train Loss: 0.000018 Acc: 1.0000
# Elapsed 158.27s, 2.93 s/epoch, 0.10 s/batch, ets 134.82s
#
# Test set: Average loss: 1.3222, Accuracy: 18/30 (60%)
#
# Epoch: 54
# Train Loss: 0.000017 Acc: 1.0000
# Elapsed 161.09s, 2.93 s/epoch, 0.10 s/batch, ets 131.80s
#
# Test set: Average loss: 1.3226, Accuracy: 18/30 (60%)
#
# Epoch: 55
# Train Loss: 0.000016 Acc: 1.0000
# Elapsed 164.03s, 2.93 s/epoch, 0.10 s/batch, ets 128.88s
#
# Test set: Average loss: 1.3338, Accuracy: 18/30 (60%)
#
# Epoch: 56
# Train Loss: 0.000016 Acc: 1.0000
# Elapsed 166.92s, 2.93 s/epoch, 0.10 s/batch, ets 125.92s
#
# Test set: Average loss: 1.3369, Accuracy: 18/30 (60%)
#
# Epoch: 57
# Train Loss: 0.000015 Acc: 1.0000
# Elapsed 169.74s, 2.93 s/epoch, 0.10 s/batch, ets 122.91s
#
# Test set: Average loss: 1.3430, Accuracy: 18/30 (60%)
#
# Epoch: 58
# Train Loss: 0.000014 Acc: 1.0000
# Elapsed 172.55s, 2.92 s/epoch, 0.10 s/batch, ets 119.91s
#
# Test set: Average loss: 1.3472, Accuracy: 18/30 (60%)
#
# Epoch: 59
# Train Loss: 0.000014 Acc: 1.0000
# Elapsed 175.37s, 2.92 s/epoch, 0.10 s/batch, ets 116.91s
#
# Test set: Average loss: 1.3578, Accuracy: 18/30 (60%)
#
# Epoch: 60
# Train Loss: 0.000013 Acc: 1.0000
# Elapsed 178.19s, 2.92 s/epoch, 0.10 s/batch, ets 113.93s
#
# Test set: Average loss: 1.3577, Accuracy: 18/30 (60%)
#
# Epoch: 61
# Train Loss: 0.000013 Acc: 1.0000
# Elapsed 181.02s, 2.92 s/epoch, 0.10 s/batch, ets 110.94s
#
# Test set: Average loss: 1.3617, Accuracy: 18/30 (60%)
#
# Epoch: 62
# Train Loss: 0.000012 Acc: 1.0000
# Elapsed 183.93s, 2.92 s/epoch, 0.10 s/batch, ets 108.02s
#
# Test set: Average loss: 1.3678, Accuracy: 18/30 (60%)
#
# Epoch: 63
# Train Loss: 0.000012 Acc: 1.0000
# Elapsed 186.81s, 2.92 s/epoch, 0.10 s/batch, ets 105.08s
#
# Test set: Average loss: 1.3698, Accuracy: 18/30 (60%)
#
# Epoch: 64
# Train Loss: 0.000011 Acc: 1.0000
# Elapsed 189.64s, 2.92 s/epoch, 0.10 s/batch, ets 102.11s
#
# Test set: Average loss: 1.3782, Accuracy: 18/30 (60%)
#
# Epoch: 65
# Train Loss: 0.000011 Acc: 1.0000
# Elapsed 192.49s, 2.92 s/epoch, 0.10 s/batch, ets 99.16s
#
# Test set: Average loss: 1.3839, Accuracy: 18/30 (60%)
#
# Epoch: 66
# Train Loss: 0.000010 Acc: 1.0000
# Elapsed 195.30s, 2.91 s/epoch, 0.10 s/batch, ets 96.19s
#
# Test set: Average loss: 1.3871, Accuracy: 18/30 (60%)
#
# Epoch: 67
# Train Loss: 0.000010 Acc: 1.0000
# Elapsed 198.12s, 2.91 s/epoch, 0.10 s/batch, ets 93.23s
#
# Test set: Average loss: 1.3910, Accuracy: 18/30 (60%)
#
# Epoch: 68
# Train Loss: 0.000010 Acc: 1.0000
# Elapsed 200.94s, 2.91 s/epoch, 0.10 s/batch, ets 90.28s
#
# Test set: Average loss: 1.3970, Accuracy: 18/30 (60%)
#
# Epoch: 69
# Train Loss: 0.000009 Acc: 1.0000
# Elapsed 203.77s, 2.91 s/epoch, 0.10 s/batch, ets 87.33s
#
# Test set: Average loss: 1.4006, Accuracy: 18/30 (60%)
#
# Epoch: 70
# Train Loss: 0.000009 Acc: 1.0000
# Elapsed 206.59s, 2.91 s/epoch, 0.10 s/batch, ets 84.38s
#
# Test set: Average loss: 1.4092, Accuracy: 18/30 (60%)
#
# Epoch: 71
# Train Loss: 0.000009 Acc: 1.0000
# Elapsed 209.43s, 2.91 s/epoch, 0.10 s/batch, ets 81.44s
#
# Test set: Average loss: 1.4111, Accuracy: 18/30 (60%)
#
# Epoch: 72
# Train Loss: 0.000008 Acc: 1.0000
# Elapsed 212.24s, 2.91 s/epoch, 0.10 s/batch, ets 78.50s
#
# Test set: Average loss: 1.4145, Accuracy: 18/30 (60%)
#
# Epoch: 73
# Train Loss: 0.000008 Acc: 1.0000
# Elapsed 215.06s, 2.91 s/epoch, 0.10 s/batch, ets 75.56s
#
# Test set: Average loss: 1.4206, Accuracy: 18/30 (60%)
#
# Epoch: 74
# Train Loss: 0.000008 Acc: 1.0000
# Elapsed 217.91s, 2.91 s/epoch, 0.10 s/batch, ets 72.64s
#
# Test set: Average loss: 1.4246, Accuracy: 18/30 (60%)
#
# Epoch: 75
# Train Loss: 0.000008 Acc: 1.0000
# Elapsed 220.74s, 2.90 s/epoch, 0.10 s/batch, ets 69.71s
#
# Test set: Average loss: 1.4260, Accuracy: 18/30 (60%)
#
# Epoch: 76
# Train Loss: 0.000007 Acc: 1.0000
# Elapsed 223.58s, 2.90 s/epoch, 0.10 s/batch, ets 66.78s
#
# Test set: Average loss: 1.4354, Accuracy: 18/30 (60%)
#
# Epoch: 77
# Train Loss: 0.000007 Acc: 1.0000
# Elapsed 226.40s, 2.90 s/epoch, 0.10 s/batch, ets 63.86s
#
# Test set: Average loss: 1.4360, Accuracy: 17/30 (57%)
#
# Epoch: 78
# Train Loss: 0.000007 Acc: 1.0000
# Elapsed 229.23s, 2.90 s/epoch, 0.10 s/batch, ets 60.93s
#
# Test set: Average loss: 1.4429, Accuracy: 18/30 (60%)
#
# Epoch: 79
# Train Loss: 0.000007 Acc: 1.0000
# Elapsed 232.04s, 2.90 s/epoch, 0.10 s/batch, ets 58.01s
#
# Test set: Average loss: 1.4450, Accuracy: 18/30 (60%)
#
# Epoch: 80
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 234.89s, 2.90 s/epoch, 0.10 s/batch, ets 55.10s
#
# Test set: Average loss: 1.4493, Accuracy: 17/30 (57%)
#
# Epoch: 81
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 237.71s, 2.90 s/epoch, 0.10 s/batch, ets 52.18s
#
# Test set: Average loss: 1.4527, Accuracy: 17/30 (57%)
#
# Epoch: 82
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 240.53s, 2.90 s/epoch, 0.10 s/batch, ets 49.26s
#
# Test set: Average loss: 1.4579, Accuracy: 17/30 (57%)
#
# Epoch: 83
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 243.35s, 2.90 s/epoch, 0.10 s/batch, ets 46.35s
#
# Test set: Average loss: 1.4613, Accuracy: 18/30 (60%)
#
# Epoch: 84
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 246.17s, 2.90 s/epoch, 0.10 s/batch, ets 43.44s
#
# Test set: Average loss: 1.4700, Accuracy: 17/30 (57%)
#
# Epoch: 85
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 249.01s, 2.90 s/epoch, 0.10 s/batch, ets 40.54s
#
# Test set: Average loss: 1.4695, Accuracy: 17/30 (57%)
#
# Epoch: 86
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 251.84s, 2.89 s/epoch, 0.10 s/batch, ets 37.63s
#
# Test set: Average loss: 1.4713, Accuracy: 17/30 (57%)
#
# Epoch: 87
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 254.70s, 2.89 s/epoch, 0.10 s/batch, ets 34.73s
#
# Test set: Average loss: 1.4773, Accuracy: 17/30 (57%)
#
# Epoch: 88
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 257.52s, 2.89 s/epoch, 0.10 s/batch, ets 31.83s
#
# Test set: Average loss: 1.4803, Accuracy: 17/30 (57%)
#
# Epoch: 89
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 260.41s, 2.89 s/epoch, 0.10 s/batch, ets 28.93s
#
# Test set: Average loss: 1.4843, Accuracy: 17/30 (57%)
#
# Epoch: 90
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 263.25s, 2.89 s/epoch, 0.10 s/batch, ets 26.04s
#
# Test set: Average loss: 1.4904, Accuracy: 17/30 (57%)
#
# Epoch: 91
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 266.10s, 2.89 s/epoch, 0.10 s/batch, ets 23.14s
#
# Test set: Average loss: 1.4944, Accuracy: 17/30 (57%)
#
# Epoch: 92
# Train Loss: 0.000004 Acc: 1.0000
# Elapsed 268.94s, 2.89 s/epoch, 0.10 s/batch, ets 20.24s
#
# Test set: Average loss: 1.4959, Accuracy: 17/30 (57%)
#
# Epoch: 93
# Train Loss: 0.000004 Acc: 1.0000
# Elapsed 271.78s, 2.89 s/epoch, 0.10 s/batch, ets 17.35s
#
# Test set: Average loss: 1.4971, Accuracy: 17/30 (57%)
#
# Epoch: 94
# Train Loss: 0.000004 Acc: 1.0000
# Elapsed 274.61s, 2.89 s/epoch, 0.10 s/batch, ets 14.45s
#
# Test set: Average loss: 1.5024, Accuracy: 17/30 (57%)
#
# Epoch: 95
# Train Loss: 0.000004 Acc: 1.0000
# Elapsed 277.44s, 2.89 s/epoch, 0.10 s/batch, ets 11.56s
#
# Test set: Average loss: 1.5118, Accuracy: 17/30 (57%)
#
# Epoch: 96
# Train Loss: 0.000004 Acc: 1.0000
# Elapsed 280.26s, 2.89 s/epoch, 0.10 s/batch, ets 8.67s
#
# Test set: Average loss: 1.5087, Accuracy: 17/30 (57%)
#
# Epoch: 97
# Train Loss: 0.000004 Acc: 1.0000
# Elapsed 283.09s, 2.89 s/epoch, 0.10 s/batch, ets 5.78s
#
# Test set: Average loss: 1.5147, Accuracy: 17/30 (57%)
#
# Epoch: 98
# Train Loss: 0.000004 Acc: 1.0000
# Elapsed 285.91s, 2.89 s/epoch, 0.10 s/batch, ets 2.89s
#
# Test set: Average loss: 1.5178, Accuracy: 17/30 (57%)
#
# Epoch: 99
# Train Loss: 0.000004 Acc: 1.0000
# Elapsed 288.75s, 2.89 s/epoch, 0.10 s/batch, ets 0.00s
#
# Test set: Average loss: 1.5220, Accuracy: 17/30 (57%)
#
# Total time: 288.88, Best Loss: 0.607

# %% [markdown]
# ## <font style="color:blue">4.10. Loss and Accuracy Plot</font>

# %%
plot_loss_accuracy(train_loss=[train_loss], 
                   val_loss=[val_loss], 
                   train_acc=[train_acc], 
                   val_acc=[val_acc], 
                   colors=['blue'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# # <font style="color:blue">5. Sample Prediction</font>
#
# Show some sample predictions.

# %% [markdown]
# ## <font style="color:blue">5.1. Make Predictions</font>

# %%
def prediction(model, device, batch_input):
    
    # send model to cpu/cuda according to your system configuration
    model.to(device)
    
    # it is important to do model.eval() before prediction
    model.eval()

    data = batch_input.to(device)

    output = model(data)

    # Score to probability using softmax
    prob = F.softmax(output, dim=1)

    # get the max probability
    pred_prob = prob.data.max(dim=1)[0]
    
    # get the index of the max probability
    pred_index = prob.data.max(dim=1)[1]
    
    return pred_index.cpu().numpy(), pred_prob.cpu().numpy()

# %% [markdown]
# ## <font style="color:blue">5.2. Get predictions on a batch</font>

# %%
def get_sample_prediction(model, data_root, mean, std):
    batch_size = 15

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
        
        
    
    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))
    
    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())
    
    data_len = test_dataset.__len__()
    
    interval = int(data_len/batch_size)
    
    imgs = []
    inputs = []
    targets = []
    for i in range(batch_size):
        index = i * interval
        trans_input, target = test_dataset_trans.__getitem__(index)
        img, _ = test_dataset.__getitem__(index)
        
        imgs.append(img)
        inputs.append(trans_input)
        targets.append(target)
        
    inputs = torch.stack(inputs)
        
    cls, prob = prediction(model, device, batch_input=inputs)
    
    plt.style.use('default')
    plt.rcParams["figure.figsize"] = (15, 9)
    fig = plt.figure()
    
    
    for i, target in enumerate(targets):
        plt.subplot(3, 5, i+1)
        img = transforms.functional.to_pil_image(imgs[i])
        plt.imshow(img)
        plt.gca().set_title('P:{0}({1:.2}), T:{2}'.format(test_dataset.classes[cls[i]], 
                                                     prob[i], 
                                                     test_dataset.classes[targets[i]]))
    fig.savefig('sample_prediction.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:blue">5.3. Load Model and Run Inference</font>

# %%
m = MyModel()

m = load_model(m)

train_config = TrainingConfiguration()

test_data_path = os.path.join(train_config.data_root, 'validation')

train_data_path = os.path.join(train_config.data_root, 'training')

mean, std = get_mean_std(train_data_path)


get_sample_prediction(m, test_data_path, mean, std)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2400, 0.2356, 0.2306])

# %% [markdown]
# You can see that even though the network is trained on a very small subset if data, the predictions are not that bad. This means that our model is ready to be trained.

# %% [markdown]
# # <font style="color:red">6. Display Mistakes [15 points] </font>
# In the above code, sample predictions were displayed. But correct predictions are hardly of any use. You should write a similar function which displays only the mistakes made by the network.
#
# **You have to display only 15 images.**

# %%
def get_sample_incorrect_prediction(model, test_data_path, mean, std):
    batch_size = 15

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
        
        
    test_loader = data_loader(test_data_path, 
                          transform=image_common_transforms(mean, std),
                          batch_size=batch_size, 
                          shuffle=False, 
                          num_workers=num_workers)
    # original image dataset
    test_dataset = datasets.ImageFolder(root=test_data_path, transform=image_preprocess_transforms())

    index = 0
    imgs = []
    preds = []
    probs = []
    targets = []
    for data, target in test_loader:
        cls, prob = prediction(model, device, batch_input=data)
        for i in range(len(target)):
            if cls[i] != target[i]:
                img, _ = test_dataset.__getitem__(index+i)
                imgs.append(img)
                preds.append(cls[i])
                probs.append(prob[i])
                targets.append(target[i])
                #print('{} index: {}, tgt: {}, pred: {}, prob: {}'.format(num_incorrect, index+i, target[i], cls[i], prob[i]))
                if len(targets) >= 15:
                    break
        index += batch_size
        if len(targets) >= 15:
            break
    
    plt.style.use('default')
    plt.rcParams["figure.figsize"] = (15, 9)
    fig = plt.figure()
    
    
    for i, target in enumerate(targets):
        plt.subplot(3, 5, i+1)
        img = transforms.functional.to_pil_image(imgs[i])
        plt.imshow(img)
        plt.gca().set_title('P:{0}({1:.2}), T:{2}'.format(test_dataset.classes[preds[i]], 
                                                     probs[i], 
                                                     test_dataset.classes[targets[i]]))
    fig.savefig('sample_prediction.png')
    plt.show()
    
    return

# %%
m = MyModel()

m = load_model(m)

train_config = TrainingConfiguration()

test_data_path = os.path.join(train_config.data_root, 'validation')

train_data_path = os.path.join(train_config.data_root, 'training')

mean, std = get_mean_std(train_data_path)


get_sample_incorrect_prediction(m, test_data_path, mean, std)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2400, 0.2356, 0.2306])

# %% [markdown]
# After you have completed the assignment, <font style="color:red">upload and submit the notebook on the portal</font> so that we can check and provide feedback.
